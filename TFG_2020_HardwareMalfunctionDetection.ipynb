# %% [markdown]
# ## Real-time audio classification to detect scientific hardware malfunction.

# %% [markdown]
# **Final Degree Thesis UPF / 2020**
#
# Genís Plaja i Roglans
# <br>
# _Thesis supervisor:_ Dr. Xavier Serra i Casals
# <br>
# Dept. of Information and Communication Technologies
# <br>
# Universitat Pompeu Fabra

# %% [markdown]
# **Notebook based in:** _Lecture1_IntroWithACaseStudy_ of the MIR course from the MSc in Sound and Music Computing.

# %% [markdown]
# ## Classification task: Scientific hardware malfunction detection and prevention.
#
# * The principal aim of this project is to design an automatic audio classification methodology to solve real life problems related to scientific hardware malfunction.
# * This notebook is based on a specific use case. We are trying to detect when a GC-MS (Gas Chromatography - Mass Spectometry) from DIMOCAT (Universitat de Girona) research group suffers from a technical failure.

# %%
#If not installed, install Essentia. 
# This cell is for running the notebook in Colab
import importlib.util
if importlib.util.find_spec('essentia') is None:
  # !pip install essentia

# %%
#Basic imports
import os
import matplotlib.pyplot as plt
import essentia.standard as ess
import numpy as np

# %% [markdown]
# ## Collecting raw data and investigating its nature
#
# ### Creating dataset

# %%
#This cell downloads a subset of the UIOWA:MIS dataset
import urllib.request
import zipfile
import os, sys,shutil

# %% [markdown]
# **Collect file lists for each case**

# %%
main_data_dir = 'audios/'
segments_path = 'audios/segments/'
## If segment exists, delete it ##
if os.path.exists(segments_path):
    shutil.rmtree(segments_path)
    
inst_files = dict()#dictionary containing for each case a list that carries dictionaries
for root, dirs, files in os.walk(main_data_dir):
    for file in files:
        #Let's only keep forte recordings indicated with .wav/.WAV in the file name
        if (file.endswith('.wav') or file.endswith('.WAV')):
            file_name = os.path.join(root,file)
            state = file.split('.')[0]#case name is coded in the filename between the points
            if(len(state) > 0):#avoid MACOS files that start with ._
                files_state = inst_files.get(state)
                if files_state == None:
                    files_state = [file_name]
                else:
                    files_state.append(file_name)
                inst_files[state] = files_state

#Let's print the list of files
inst_files
# Out:
# {'silence': ['audios/silence/silence.iphone.wav',
#   'audios/silence/silence.zoom.wav'],
#  'working': ['audios/working/working.iphone.wav',
#   'audios/working/working.zoom.WAV'],
#  'cooling': ['audios/cooling/cooling.zoom.WAV',
#   'audios/cooling/cooling.iphone.wav']}

# %% [markdown]
# ### Investigating and preprocessing raw data
#
# It is often very useful to first check a few samples from the dataset to decide what preprocessing steps are required. Let's have a look at the waveform of one sample recording for each instrument

# %%
# Raw-data preprocess analysis parameters
fs = 44100

num_states = len(inst_files.keys())
print("Sample waveform plots")
plt.figure(1, figsize=(5 * num_states, 3))
file_ind_inlist = 0 # 0: let's take the first file in the list for sample plots
for i,state in enumerate(inst_files.keys()):
    sample_file = inst_files[state][file_ind_inlist]
    x = ess.MonoLoader(filename = sample_file, sampleRate = fs)()
    
    plt.subplot(1,num_states,(i+1))
    #We take only the first 44100*4 samples of a single audio of each class, hence 4 seconds.
    plt.plot(x[0:(44100*4)])
    plt.title(state)
# Out:
# Sample waveform plots

# %% [markdown]
# We can that the _silence_ class has a very distinguished shape, although we notice some points in the shape that might be outliers, considering the prior knowledge of how the _silence_ class sounds like.
#
# We can also see that the _working_ and _cooling_ plots are quite similar in shape, and that seem to be very noisy sounds. However, the level of the two sounds are different.
#
#
# ### Preprocessing of raw data: Segmentation, splitting, alignment,...

# %% [markdown]
# While common preprocessing steps (such as amplitude normalisation) exist, there is often some dataset and task specific preprocessing tasks required for grouping, cleaning, and format change.
#
# Regarding our dataset, it is made by very long pieces of audio, so the task will be to divide them by a specific window and hop size (to apply some overlapping), apply a window to obtain a smooth contours and avoid outliers.

# %%
# Raw-data preprocess analysis parameters
windowSize = 4096 * 4
hopSize = 4096 * 2
# TO DO: ENFINESTRAR
# Let's put in a container to be able to use as a single argument in function calls
params = {"fs":fs, "windowSize":windowSize, "hopSize":hopSize}

# %% [markdown]
# We will create a _segments_ folder, where we will save all the audios slices created.

# %%
segments_dir = os.path.join(main_data_dir,'segments')
if not os.path.exists(segments_dir): #creating the directory
    os.mkdir(segments_dir)

segment_files = []
for state, files in inst_files.items():
    file_count = 0
    for sample_file in files:
        print(sample_file)
        x = ess.MonoLoader(filename = sample_file, sampleRate = fs)()
        for frame in ess.FrameGenerator(x, frameSize = windowSize, hopSize = hopSize, startFromZero = True):
            if (file_count<700):
                if 'zoom' in sample_file:
                    filename = os.path.join(segments_dir, state + '_zoom_' + str(file_count) + '.wav')
                    print(filename)
                    ess.MonoWriter(filename = filename, format = 'wav', sampleRate = fs)(frame)
                    file_count +=1
                    segment_files.append(filename)
                if not 'zoom' in sample_file:
                    filename = os.path.join(segments_dir, state + '_' + str(file_count) + '.wav')
                    print(filename)
                    ess.MonoWriter(filename = filename, format = 'wav', sampleRate = fs)(frame)
                    file_count +=1
                    segment_files.append(filename)
        file_count = 0
        #n = len(x)
        #file_count = 1
        #k = np.arange(0, n, fs)
        #for i in k:
            #audioBlock = x[i*5:min(i + 5*fs - 1, n)]
            #audioBlock_norm = audioBlock / np.max(np.abs(audioBlock))
            #filename = os.path.join(segments_dir, state + '_' + str(file_count) + '.wav')
            #print(filename)
            #ess.MonoWriter(filename = filename, format = 'wav', sampleRate = fs)(audioBlock_norm)
            #file_count +=1
            #segment_files.append(filename)

print(len(segment_files),'segment files created')
# Out:
# audios/silence/silence.iphone.wav
# audios/segments/silence_0.wav
# audios/segments/silence_1.wav
# audios/segments/silence_2.wav
# audios/segments/silence_3.wav
# audios/segments/silence_4.wav
# audios/segments/silence_5.wav
# audios/segments/silence_6.wav
# audios/segments/silence_7.wav
# audios/segments/silence_8.wav
# audios/segments/silence_9.wav
# audios/segments/silence_10.wav
# audios/segments/silence_11.wav
# audios/segments/silence_12.wav
# audios/segments/silence_13.wav
# audios/segments/silence_14.wav
# audios/segments/silence_15.wav
# audios/segments/silence_16.wav
# audios/segments/silence_17.wav
# audios/segments/silence_18.wav
# audios/segments/silence_19.wav
# audios/segments/silence_20.wav
# audios/segments/silence_21.wav
# audios/segments/silence_22.wav
# audios/segments/silence_23.wav
# audios/segments/silence_24.wav
# audios/segments/silence_25.wav
# audios/segments/silence_26.wav
# audios/segments/silence_27.wav
# audios/segments/silence_28.wav
# audios/segments/silence_29.wav
# audios/segments/silence_30.wav
# audios/segments/silence_31.wav
# audios/segments/silence_32.wav
# audios/segments/silence_33.wav
# audios/segments/silence_34.wav
# audios/segments/silence_35.wav
# audios/segments/silence_36.wav
# audios/segments/silence_37.wav
# audios/segments/silence_38.wav
# audios/segments/silence_39.wav
# audios/segments/silence_40.wav
# audios/segments/silence_41.wav
# audios/segments/silence_42.wav
# audios/segments/silence_43.wav
# audios/segments/silence_44.wav
# audios/segments/silence_45.wav
# audios/segments/silence_46.wav
# audios/segments/silence_47.wav
# audios/segments/silence_48.wav
# audios/segments/silence_49.wav
# audios/segments/silence_50.wav
# audios/segments/silence_51.wav
# audios/segments/silence_52.wav
# audios/segments/silence_53.wav
# audios/segments/silence_54.wav
# audios/segments/silence_55.wav
# audios/segments/silence_56.wav
# audios/segments/silence_57.wav
# audios/segments/silence_58.wav
# audios/segments/silence_59.wav
# audios/segments/silence_60.wav
# audios/segments/silence_61.wav
# audios/segments/silence_62.wav
# audios/segments/silence_63.wav
# audios/segments/silence_64.wav
# audios/segments/silence_65.wav
# audios/segments/silence_66.wav
# audios/segments/silence_67.wav
# audios/segments/silence_68.wav
# audios/segments/silence_69.wav
# audios/segments/silence_70.wav
# audios/segments/silence_71.wav
# audios/segments/silence_72.wav
# audios/segments/silence_73.wav
# audios/segments/silence_74.wav
# audios/segments/silence_75.wav
# audios/segments/silence_76.wav
# audios/segments/silence_77.wav
# audios/segments/silence_78.wav
# audios/segments/silence_79.wav
# audios/segments/silence_80.wav
# audios/segments/silence_81.wav
# audios/segments/silence_82.wav
# audios/segments/silence_83.wav
# audios/segments/silence_84.wav
# audios/segments/silence_85.wav
# audios/segments/silence_86.wav
# audios/segments/silence_87.wav
# audios/segments/silence_88.wav
# audios/segments/silence_89.wav
# audios/segments/silence_90.wav
# audios/segments/silence_91.wav
# audios/segments/silence_92.wav
# audios/segments/silence_93.wav
# audios/segments/silence_94.wav
# audios/segments/silence_95.wav
# audios/segments/silence_96.wav
# audios/segments/silence_97.wav
# audios/segments/silence_98.wav
# audios/segments/silence_99.wav
# audios/segments/silence_100.wav
# audios/segments/silence_101.wav
# audios/segments/silence_102.wav
# audios/segments/silence_103.wav
# audios/segments/silence_104.wav
# audios/segments/silence_105.wav
# audios/segments/silence_106.wav
# audios/segments/silence_107.wav
# audios/segments/silence_108.wav
# audios/segments/silence_109.wav
# audios/segments/silence_110.wav
# audios/segments/silence_111.wav
# audios/segments/silence_112.wav
# audios/segments/silence_113.wav
# audios/segments/silence_114.wav
# audios/segments/silence_115.wav
# audios/segments/silence_116.wav
# audios/segments/silence_117.wav
# audios/segments/silence_118.wav
# audios/segments/silence_119.wav
# audios/segments/silence_120.wav
# audios/segments/silence_121.wav
# audios/segments/silence_122.wav
# audios/segments/silence_123.wav
# audios/segments/silence_124.wav
# audios/segments/silence_125.wav
# audios/segments/silence_126.wav
# audios/segments/silence_127.wav
# audios/segments/silence_128.wav
# audios/segments/silence_129.wav
# audios/segments/silence_130.wav
# audios/segments/silence_131.wav
# audios/segments/silence_132.wav
# audios/segments/silence_133.wav
# audios/segments/silence_134.wav
# audios/segments/silence_135.wav
# audios/segments/silence_136.wav
# audios/segments/silence_137.wav
# audios/segments/silence_138.wav
# audios/segments/silence_139.wav
# audios/segments/silence_140.wav
# audios/segments/silence_141.wav
# audios/segments/silence_142.wav
# audios/segments/silence_143.wav
# audios/segments/silence_144.wav
# audios/segments/silence_145.wav
# audios/segments/silence_146.wav
# audios/segments/silence_147.wav
# audios/segments/silence_148.wav
# audios/segments/silence_149.wav
# audios/segments/silence_150.wav
# audios/segments/silence_151.wav
# audios/segments/silence_152.wav
# audios/segments/silence_153.wav
# audios/segments/silence_154.wav
# audios/segments/silence_155.wav
# audios/segments/silence_156.wav
# audios/segments/silence_157.wav
# audios/segments/silence_158.wav
# audios/segments/silence_159.wav
# audios/segments/silence_160.wav
# audios/segments/silence_161.wav
# audios/segments/silence_162.wav
# audios/segments/silence_163.wav
# audios/segments/silence_164.wav
# audios/segments/silence_165.wav
# audios/segments/silence_166.wav
# audios/segments/silence_167.wav
# audios/segments/silence_168.wav
# audios/segments/silence_169.wav
# audios/segments/silence_170.wav
# audios/segments/silence_171.wav
# audios/segments/silence_172.wav
# audios/segments/silence_173.wav
# audios/segments/silence_174.wav
# audios/segments/silence_175.wav
# audios/segments/silence_176.wav
# audios/segments/silence_177.wav
# audios/segments/silence_178.wav
# audios/segments/silence_179.wav
# audios/segments/silence_180.wav
# audios/segments/silence_181.wav
# audios/segments/silence_182.wav
# audios/segments/silence_183.wav
# audios/segments/silence_184.wav
# audios/segments/silence_185.wav
# audios/segments/silence_186.wav
# audios/segments/silence_187.wav
# audios/segments/silence_188.wav
# audios/segments/silence_189.wav
# audios/segments/silence_190.wav
# audios/segments/silence_191.wav
# audios/segments/silence_192.wav
# audios/segments/silence_193.wav
# audios/segments/silence_194.wav
# audios/segments/silence_195.wav
# audios/segments/silence_196.wav
# audios/segments/silence_197.wav
# audios/segments/silence_198.wav
# audios/segments/silence_199.wav
# audios/segments/silence_200.wav
# audios/segments/silence_201.wav
# audios/segments/silence_202.wav
# audios/segments/silence_203.wav
# audios/segments/silence_204.wav
# audios/segments/silence_205.wav
# audios/segments/silence_206.wav
# audios/segments/silence_207.wav
# audios/segments/silence_208.wav
# audios/segments/silence_209.wav
# audios/segments/silence_210.wav
# audios/segments/silence_211.wav
# audios/segments/silence_212.wav
# audios/segments/silence_213.wav
# audios/segments/silence_214.wav
# audios/segments/silence_215.wav
# audios/segments/silence_216.wav
# audios/segments/silence_217.wav
# audios/segments/silence_218.wav
# audios/segments/silence_219.wav
# audios/segments/silence_220.wav
# audios/segments/silence_221.wav
# audios/segments/silence_222.wav
# audios/segments/silence_223.wav
# audios/segments/silence_224.wav
# audios/segments/silence_225.wav
# audios/segments/silence_226.wav
# audios/segments/silence_227.wav
# audios/segments/silence_228.wav
# audios/segments/silence_229.wav
# audios/segments/silence_230.wav
# audios/segments/silence_231.wav
# audios/segments/silence_232.wav
# audios/segments/silence_233.wav
# audios/segments/silence_234.wav
# audios/segments/silence_235.wav
# audios/segments/silence_236.wav
# audios/segments/silence_237.wav
# audios/segments/silence_238.wav
# audios/segments/silence_239.wav
# audios/segments/silence_240.wav
# audios/segments/silence_241.wav
# audios/segments/silence_242.wav
# audios/segments/silence_243.wav
# audios/segments/silence_244.wav
# audios/segments/silence_245.wav
# audios/segments/silence_246.wav
# audios/segments/silence_247.wav
# audios/segments/silence_248.wav
# audios/segments/silence_249.wav
# audios/segments/silence_250.wav
# audios/segments/silence_251.wav
# audios/segments/silence_252.wav
# audios/segments/silence_253.wav
# audios/segments/silence_254.wav
# audios/segments/silence_255.wav
# audios/segments/silence_256.wav
# audios/segments/silence_257.wav
# audios/segments/silence_258.wav
# audios/segments/silence_259.wav
# audios/segments/silence_260.wav
# audios/segments/silence_261.wav
# audios/segments/silence_262.wav
# audios/segments/silence_263.wav
# audios/segments/silence_264.wav
# audios/segments/silence_265.wav
# audios/segments/silence_266.wav
# audios/segments/silence_267.wav
# audios/segments/silence_268.wav
# audios/segments/silence_269.wav
# audios/segments/silence_270.wav
# audios/segments/silence_271.wav
# audios/segments/silence_272.wav
# audios/segments/silence_273.wav
# audios/segments/silence_274.wav
# audios/segments/silence_275.wav
# audios/segments/silence_276.wav
# audios/segments/silence_277.wav
# audios/segments/silence_278.wav
# audios/segments/silence_279.wav
# audios/segments/silence_280.wav
# audios/segments/silence_281.wav
# audios/segments/silence_282.wav
# audios/segments/silence_283.wav
# audios/segments/silence_284.wav
# audios/segments/silence_285.wav
# audios/segments/silence_286.wav
# audios/segments/silence_287.wav
# audios/segments/silence_288.wav
# audios/segments/silence_289.wav
# audios/segments/silence_290.wav
# audios/segments/silence_291.wav
# audios/segments/silence_292.wav
# audios/segments/silence_293.wav
# audios/segments/silence_294.wav
# audios/segments/silence_295.wav
# audios/segments/silence_296.wav
# audios/segments/silence_297.wav
# audios/segments/silence_298.wav
# audios/segments/silence_299.wav
# audios/segments/silence_300.wav
# audios/segments/silence_301.wav
# audios/segments/silence_302.wav
# audios/segments/silence_303.wav
# audios/segments/silence_304.wav
# audios/segments/silence_305.wav
# audios/segments/silence_306.wav
# audios/segments/silence_307.wav
# audios/segments/silence_308.wav
# audios/segments/silence_309.wav
# audios/segments/silence_310.wav
# audios/segments/silence_311.wav
# audios/segments/silence_312.wav
# audios/segments/silence_313.wav
# audios/segments/silence_314.wav
# audios/segments/silence_315.wav
# audios/segments/silence_316.wav
# audios/segments/silence_317.wav
# audios/segments/silence_318.wav
# audios/segments/silence_319.wav
# audios/segments/silence_320.wav
# audios/segments/silence_321.wav
# audios/segments/silence_322.wav
# audios/segments/silence_323.wav
# audios/segments/silence_324.wav
# audios/segments/silence_325.wav
# audios/segments/silence_326.wav
# audios/segments/silence_327.wav
# audios/segments/silence_328.wav
# audios/segments/silence_329.wav
# audios/segments/silence_330.wav
# audios/segments/silence_331.wav
# audios/segments/silence_332.wav
# audios/segments/silence_333.wav
# audios/segments/silence_334.wav
# audios/segments/silence_335.wav
# audios/segments/silence_336.wav
# audios/segments/silence_337.wav
# audios/segments/silence_338.wav
# audios/segments/silence_339.wav
# audios/segments/silence_340.wav
# audios/segments/silence_341.wav
# audios/segments/silence_342.wav
# audios/segments/silence_343.wav
# audios/segments/silence_344.wav
# audios/segments/silence_345.wav
# audios/segments/silence_346.wav
# audios/segments/silence_347.wav
# audios/segments/silence_348.wav
# audios/segments/silence_349.wav
# audios/segments/silence_350.wav
# audios/segments/silence_351.wav
# audios/segments/silence_352.wav
# audios/segments/silence_353.wav
# audios/segments/silence_354.wav
# audios/segments/silence_355.wav
# audios/segments/silence_356.wav
# audios/segments/silence_357.wav
# audios/segments/silence_358.wav
# audios/segments/silence_359.wav
# audios/segments/silence_360.wav
# audios/segments/silence_361.wav
# audios/segments/silence_362.wav
# audios/segments/silence_363.wav
# audios/segments/silence_364.wav
# audios/segments/silence_365.wav
# audios/segments/silence_366.wav
# audios/segments/silence_367.wav
# audios/segments/silence_368.wav
# audios/segments/silence_369.wav
# audios/segments/silence_370.wav
# audios/segments/silence_371.wav
# audios/segments/silence_372.wav
# audios/segments/silence_373.wav
# audios/segments/silence_374.wav
# audios/segments/silence_375.wav
# audios/segments/silence_376.wav
# audios/segments/silence_377.wav
# audios/segments/silence_378.wav
# audios/segments/silence_379.wav
# audios/segments/silence_380.wav
# audios/segments/silence_381.wav
# audios/segments/silence_382.wav
# audios/segments/silence_383.wav
# audios/segments/silence_384.wav
# audios/segments/silence_385.wav
# audios/segments/silence_386.wav
# audios/segments/silence_387.wav
# audios/segments/silence_388.wav
# audios/segments/silence_389.wav
# audios/segments/silence_390.wav
# audios/segments/silence_391.wav
# audios/segments/silence_392.wav
# audios/segments/silence_393.wav
# audios/segments/silence_394.wav
# audios/segments/silence_395.wav
# audios/segments/silence_396.wav
# audios/segments/silence_397.wav
# audios/segments/silence_398.wav
# audios/segments/silence_399.wav
# audios/segments/silence_400.wav
# audios/segments/silence_401.wav
# audios/segments/silence_402.wav
# audios/segments/silence_403.wav
# audios/segments/silence_404.wav
# audios/segments/silence_405.wav
# audios/segments/silence_406.wav
# audios/segments/silence_407.wav
# audios/segments/silence_408.wav
# audios/segments/silence_409.wav
# audios/segments/silence_410.wav
# audios/segments/silence_411.wav
# audios/segments/silence_412.wav
# audios/segments/silence_413.wav
# audios/segments/silence_414.wav
# audios/segments/silence_415.wav
# audios/segments/silence_416.wav
# audios/segments/silence_417.wav
# audios/segments/silence_418.wav
# audios/segments/silence_419.wav
# audios/segments/silence_420.wav
# audios/segments/silence_421.wav
# audios/segments/silence_422.wav
# audios/segments/silence_423.wav
# audios/segments/silence_424.wav
# audios/segments/silence_425.wav
# audios/segments/silence_426.wav
# audios/segments/silence_427.wav
# audios/segments/silence_428.wav
# audios/segments/silence_429.wav
# audios/segments/silence_430.wav
# audios/segments/silence_431.wav
# audios/segments/silence_432.wav
# audios/segments/silence_433.wav
# audios/segments/silence_434.wav
# audios/segments/silence_435.wav
# audios/segments/silence_436.wav
# audios/segments/silence_437.wav
# audios/segments/silence_438.wav
# audios/segments/silence_439.wav
# audios/segments/silence_440.wav
# audios/segments/silence_441.wav
# audios/segments/silence_442.wav
# audios/segments/silence_443.wav
# audios/segments/silence_444.wav
# audios/segments/silence_445.wav
# audios/segments/silence_446.wav
# audios/segments/silence_447.wav
# audios/segments/silence_448.wav
# audios/segments/silence_449.wav
# audios/segments/silence_450.wav
# audios/segments/silence_451.wav
# audios/segments/silence_452.wav
# audios/segments/silence_453.wav
# audios/segments/silence_454.wav
# audios/segments/silence_455.wav
# audios/segments/silence_456.wav
# audios/segments/silence_457.wav
# audios/segments/silence_458.wav
# audios/segments/silence_459.wav
# audios/segments/silence_460.wav
# audios/segments/silence_461.wav
# audios/segments/silence_462.wav
# audios/segments/silence_463.wav
# audios/segments/silence_464.wav
# audios/segments/silence_465.wav
# audios/segments/silence_466.wav
# audios/segments/silence_467.wav
# audios/segments/silence_468.wav
# audios/segments/silence_469.wav
# audios/segments/silence_470.wav
# audios/segments/silence_471.wav
# audios/segments/silence_472.wav
# audios/segments/silence_473.wav
# audios/segments/silence_474.wav
# audios/segments/silence_475.wav
# audios/segments/silence_476.wav
# audios/segments/silence_477.wav
# audios/segments/silence_478.wav
# audios/segments/silence_479.wav
# audios/segments/silence_480.wav
# audios/segments/silence_481.wav
# audios/segments/silence_482.wav
# audios/segments/silence_483.wav
# audios/segments/silence_484.wav
# audios/segments/silence_485.wav
# audios/segments/silence_486.wav
# audios/segments/silence_487.wav
# audios/segments/silence_488.wav
# audios/segments/silence_489.wav
# audios/segments/silence_490.wav
# audios/segments/silence_491.wav
# audios/segments/silence_492.wav
# audios/segments/silence_493.wav
# audios/segments/silence_494.wav
# audios/segments/silence_495.wav
# audios/segments/silence_496.wav
# audios/segments/silence_497.wav
# audios/segments/silence_498.wav
# audios/segments/silence_499.wav
# audios/segments/silence_500.wav
# audios/segments/silence_501.wav
# audios/segments/silence_502.wav
# audios/segments/silence_503.wav
# audios/segments/silence_504.wav
# audios/segments/silence_505.wav
# audios/segments/silence_506.wav
# audios/segments/silence_507.wav
# audios/segments/silence_508.wav
# audios/segments/silence_509.wav
# audios/segments/silence_510.wav
# audios/segments/silence_511.wav
# audios/segments/silence_512.wav
# audios/segments/silence_513.wav
# audios/segments/silence_514.wav
# audios/segments/silence_515.wav
# audios/segments/silence_516.wav
# audios/segments/silence_517.wav
# audios/segments/silence_518.wav
# audios/segments/silence_519.wav
# audios/segments/silence_520.wav
# audios/segments/silence_521.wav
# audios/segments/silence_522.wav
# audios/segments/silence_523.wav
# audios/segments/silence_524.wav
# audios/segments/silence_525.wav
# audios/segments/silence_526.wav
# audios/segments/silence_527.wav
# audios/segments/silence_528.wav
# audios/segments/silence_529.wav
# audios/segments/silence_530.wav
# audios/segments/silence_531.wav
# audios/segments/silence_532.wav
# audios/segments/silence_533.wav
# audios/segments/silence_534.wav
# audios/segments/silence_535.wav
# audios/segments/silence_536.wav
# audios/segments/silence_537.wav
# audios/segments/silence_538.wav
# audios/segments/silence_539.wav
# audios/segments/silence_540.wav
# audios/segments/silence_541.wav
# audios/segments/silence_542.wav
# audios/segments/silence_543.wav
# audios/segments/silence_544.wav
# audios/segments/silence_545.wav
# audios/segments/silence_546.wav
# audios/segments/silence_547.wav
# audios/segments/silence_548.wav
# audios/segments/silence_549.wav
# audios/segments/silence_550.wav
# audios/segments/silence_551.wav
# audios/segments/silence_552.wav
# audios/segments/silence_553.wav
# audios/segments/silence_554.wav
# audios/segments/silence_555.wav
# audios/segments/silence_556.wav
# audios/segments/silence_557.wav
# audios/segments/silence_558.wav
# audios/segments/silence_559.wav
# audios/segments/silence_560.wav
# audios/segments/silence_561.wav
# audios/segments/silence_562.wav
# audios/segments/silence_563.wav
# audios/segments/silence_564.wav
# audios/segments/silence_565.wav
# audios/segments/silence_566.wav
# audios/segments/silence_567.wav
# audios/segments/silence_568.wav
# audios/segments/silence_569.wav
# audios/segments/silence_570.wav
# audios/segments/silence_571.wav
# audios/segments/silence_572.wav
# audios/segments/silence_573.wav
# audios/segments/silence_574.wav
# audios/segments/silence_575.wav
# audios/segments/silence_576.wav
# audios/segments/silence_577.wav
# audios/segments/silence_578.wav
# audios/segments/silence_579.wav
# audios/segments/silence_580.wav
# audios/segments/silence_581.wav
# audios/segments/silence_582.wav
# audios/segments/silence_583.wav
# audios/segments/silence_584.wav
# audios/segments/silence_585.wav
# audios/segments/silence_586.wav
# audios/segments/silence_587.wav
# audios/segments/silence_588.wav
# audios/segments/silence_589.wav
# audios/segments/silence_590.wav
# audios/segments/silence_591.wav
# audios/segments/silence_592.wav
# audios/segments/silence_593.wav
# audios/segments/silence_594.wav
# audios/segments/silence_595.wav
# audios/segments/silence_596.wav
# audios/segments/silence_597.wav
# audios/segments/silence_598.wav
# audios/segments/silence_599.wav
# audios/segments/silence_600.wav
# audios/segments/silence_601.wav
# audios/segments/silence_602.wav
# audios/segments/silence_603.wav
# audios/segments/silence_604.wav
# audios/segments/silence_605.wav
# audios/segments/silence_606.wav
# audios/segments/silence_607.wav
# audios/segments/silence_608.wav
# audios/segments/silence_609.wav
# audios/segments/silence_610.wav
# audios/segments/silence_611.wav
# audios/segments/silence_612.wav
# audios/segments/silence_613.wav
# audios/segments/silence_614.wav
# audios/segments/silence_615.wav
# audios/segments/silence_616.wav
# audios/segments/silence_617.wav
# audios/segments/silence_618.wav
# audios/segments/silence_619.wav
# audios/segments/silence_620.wav
# audios/segments/silence_621.wav
# audios/segments/silence_622.wav
# audios/segments/silence_623.wav
# audios/segments/silence_624.wav
# audios/segments/silence_625.wav
# audios/segments/silence_626.wav
# audios/segments/silence_627.wav
# audios/segments/silence_628.wav
# audios/segments/silence_629.wav
# audios/segments/silence_630.wav
# audios/segments/silence_631.wav
# audios/segments/silence_632.wav
# audios/segments/silence_633.wav
# audios/segments/silence_634.wav
# audios/segments/silence_635.wav
# audios/segments/silence_636.wav
# audios/segments/silence_637.wav
# audios/segments/silence_638.wav
# audios/segments/silence_639.wav
# audios/segments/silence_640.wav
# audios/segments/silence_641.wav
# audios/segments/silence_642.wav
# audios/segments/silence_643.wav
# audios/segments/silence_644.wav
# audios/segments/silence_645.wav
# audios/segments/silence_646.wav
# audios/segments/silence_647.wav
# audios/segments/silence_648.wav
# audios/segments/silence_649.wav
# audios/segments/silence_650.wav
# audios/segments/silence_651.wav
# audios/segments/silence_652.wav
# audios/segments/silence_653.wav
# audios/segments/silence_654.wav
# audios/segments/silence_655.wav
# audios/segments/silence_656.wav
# audios/segments/silence_657.wav
# audios/segments/silence_658.wav
# audios/segments/silence_659.wav
# audios/segments/silence_660.wav
# audios/segments/silence_661.wav
# audios/segments/silence_662.wav
# audios/segments/silence_663.wav
# audios/segments/silence_664.wav
# audios/segments/silence_665.wav
# audios/segments/silence_666.wav
# audios/segments/silence_667.wav
# audios/segments/silence_668.wav
# audios/segments/silence_669.wav
# audios/segments/silence_670.wav
# audios/segments/silence_671.wav
# audios/segments/silence_672.wav
# audios/segments/silence_673.wav
# audios/segments/silence_674.wav
# audios/segments/silence_675.wav
# audios/segments/silence_676.wav
# audios/segments/silence_677.wav
# audios/segments/silence_678.wav
# audios/segments/silence_679.wav
# audios/segments/silence_680.wav
# audios/segments/silence_681.wav
# audios/segments/silence_682.wav
# audios/segments/silence_683.wav
# audios/segments/silence_684.wav
# audios/segments/silence_685.wav
# audios/segments/silence_686.wav
# audios/segments/silence_687.wav
# audios/segments/silence_688.wav
# audios/segments/silence_689.wav
# audios/segments/silence_690.wav
# audios/segments/silence_691.wav
# audios/segments/silence_692.wav
# audios/segments/silence_693.wav
# audios/segments/silence_694.wav
# audios/segments/silence_695.wav
# audios/segments/silence_696.wav
# audios/segments/silence_697.wav
# audios/segments/silence_698.wav
# audios/segments/silence_699.wav
# audios/silence/silence.zoom.wav
# audios/segments/silence_zoom_0.wav
# audios/segments/silence_zoom_1.wav
# audios/segments/silence_zoom_2.wav
# audios/segments/silence_zoom_3.wav
# audios/segments/silence_zoom_4.wav
# audios/segments/silence_zoom_5.wav
# audios/segments/silence_zoom_6.wav
# audios/segments/silence_zoom_7.wav
# audios/segments/silence_zoom_8.wav
# audios/segments/silence_zoom_9.wav
# audios/segments/silence_zoom_10.wav
# audios/segments/silence_zoom_11.wav
# audios/segments/silence_zoom_12.wav
# audios/segments/silence_zoom_13.wav
# audios/segments/silence_zoom_14.wav
# audios/segments/silence_zoom_15.wav
# audios/segments/silence_zoom_16.wav
# audios/segments/silence_zoom_17.wav
# audios/segments/silence_zoom_18.wav
# audios/segments/silence_zoom_19.wav
# audios/segments/silence_zoom_20.wav
# audios/segments/silence_zoom_21.wav
# audios/segments/silence_zoom_22.wav
# audios/segments/silence_zoom_23.wav
# audios/segments/silence_zoom_24.wav
# audios/segments/silence_zoom_25.wav
# audios/segments/silence_zoom_26.wav
# audios/segments/silence_zoom_27.wav
# audios/segments/silence_zoom_28.wav
# audios/segments/silence_zoom_29.wav
# audios/segments/silence_zoom_30.wav
# audios/segments/silence_zoom_31.wav
# audios/segments/silence_zoom_32.wav
# audios/segments/silence_zoom_33.wav
# audios/segments/silence_zoom_34.wav
# audios/segments/silence_zoom_35.wav
# audios/segments/silence_zoom_36.wav
# audios/segments/silence_zoom_37.wav
# audios/segments/silence_zoom_38.wav
# audios/segments/silence_zoom_39.wav
# audios/segments/silence_zoom_40.wav
# audios/segments/silence_zoom_41.wav
# audios/segments/silence_zoom_42.wav
# audios/segments/silence_zoom_43.wav
# audios/segments/silence_zoom_44.wav
# audios/segments/silence_zoom_45.wav
# audios/segments/silence_zoom_46.wav
# audios/segments/silence_zoom_47.wav
# audios/segments/silence_zoom_48.wav
# audios/segments/silence_zoom_49.wav
# audios/segments/silence_zoom_50.wav
# audios/segments/silence_zoom_51.wav
# audios/segments/silence_zoom_52.wav
# audios/segments/silence_zoom_53.wav
# audios/segments/silence_zoom_54.wav
# audios/segments/silence_zoom_55.wav
# audios/segments/silence_zoom_56.wav
# audios/segments/silence_zoom_57.wav
# audios/segments/silence_zoom_58.wav
# audios/segments/silence_zoom_59.wav
# audios/segments/silence_zoom_60.wav
# audios/segments/silence_zoom_61.wav
# audios/segments/silence_zoom_62.wav
# audios/segments/silence_zoom_63.wav
# audios/segments/silence_zoom_64.wav
# audios/segments/silence_zoom_65.wav
# audios/segments/silence_zoom_66.wav
# audios/segments/silence_zoom_67.wav
# audios/segments/silence_zoom_68.wav
# audios/segments/silence_zoom_69.wav
# audios/segments/silence_zoom_70.wav
# audios/segments/silence_zoom_71.wav
# audios/segments/silence_zoom_72.wav
# audios/segments/silence_zoom_73.wav
# audios/segments/silence_zoom_74.wav
# audios/segments/silence_zoom_75.wav
# audios/segments/silence_zoom_76.wav
# audios/segments/silence_zoom_77.wav
# audios/segments/silence_zoom_78.wav
# audios/segments/silence_zoom_79.wav
# audios/segments/silence_zoom_80.wav
# audios/segments/silence_zoom_81.wav
# audios/segments/silence_zoom_82.wav
# audios/segments/silence_zoom_83.wav
# audios/segments/silence_zoom_84.wav
# audios/segments/silence_zoom_85.wav
# audios/segments/silence_zoom_86.wav
# audios/segments/silence_zoom_87.wav
# audios/segments/silence_zoom_88.wav
# audios/segments/silence_zoom_89.wav
# audios/segments/silence_zoom_90.wav
# audios/segments/silence_zoom_91.wav
# audios/segments/silence_zoom_92.wav
# audios/segments/silence_zoom_93.wav
# audios/segments/silence_zoom_94.wav
# audios/segments/silence_zoom_95.wav
# audios/segments/silence_zoom_96.wav
# audios/segments/silence_zoom_97.wav
# audios/segments/silence_zoom_98.wav
# audios/segments/silence_zoom_99.wav
# audios/segments/silence_zoom_100.wav
# audios/segments/silence_zoom_101.wav
# audios/segments/silence_zoom_102.wav
# audios/segments/silence_zoom_103.wav
# audios/segments/silence_zoom_104.wav
# audios/segments/silence_zoom_105.wav
# audios/segments/silence_zoom_106.wav
# audios/segments/silence_zoom_107.wav
# audios/segments/silence_zoom_108.wav
# audios/segments/silence_zoom_109.wav
# audios/segments/silence_zoom_110.wav
# audios/segments/silence_zoom_111.wav
# audios/segments/silence_zoom_112.wav
# audios/segments/silence_zoom_113.wav
# audios/segments/silence_zoom_114.wav
# audios/segments/silence_zoom_115.wav
# audios/segments/silence_zoom_116.wav
# audios/segments/silence_zoom_117.wav
# audios/segments/silence_zoom_118.wav
# audios/segments/silence_zoom_119.wav
# audios/segments/silence_zoom_120.wav
# audios/segments/silence_zoom_121.wav
# audios/segments/silence_zoom_122.wav
# audios/segments/silence_zoom_123.wav
# audios/segments/silence_zoom_124.wav
# audios/segments/silence_zoom_125.wav
# audios/segments/silence_zoom_126.wav
# audios/segments/silence_zoom_127.wav
# audios/segments/silence_zoom_128.wav
# audios/segments/silence_zoom_129.wav
# audios/segments/silence_zoom_130.wav
# audios/segments/silence_zoom_131.wav
# audios/segments/silence_zoom_132.wav
# audios/segments/silence_zoom_133.wav
# audios/segments/silence_zoom_134.wav
# audios/segments/silence_zoom_135.wav
# audios/segments/silence_zoom_136.wav
# audios/segments/silence_zoom_137.wav
# audios/segments/silence_zoom_138.wav
# audios/segments/silence_zoom_139.wav
# audios/segments/silence_zoom_140.wav
# audios/segments/silence_zoom_141.wav
# audios/segments/silence_zoom_142.wav
# audios/segments/silence_zoom_143.wav
# audios/segments/silence_zoom_144.wav
# audios/segments/silence_zoom_145.wav
# audios/segments/silence_zoom_146.wav
# audios/segments/silence_zoom_147.wav
# audios/segments/silence_zoom_148.wav
# audios/segments/silence_zoom_149.wav
# audios/segments/silence_zoom_150.wav
# audios/segments/silence_zoom_151.wav
# audios/segments/silence_zoom_152.wav
# audios/segments/silence_zoom_153.wav
# audios/segments/silence_zoom_154.wav
# audios/segments/silence_zoom_155.wav
# audios/segments/silence_zoom_156.wav
# audios/segments/silence_zoom_157.wav
# audios/segments/silence_zoom_158.wav
# audios/segments/silence_zoom_159.wav
# audios/segments/silence_zoom_160.wav
# audios/segments/silence_zoom_161.wav
# audios/segments/silence_zoom_162.wav
# audios/segments/silence_zoom_163.wav
# audios/segments/silence_zoom_164.wav
# audios/segments/silence_zoom_165.wav
# audios/segments/silence_zoom_166.wav
# audios/segments/silence_zoom_167.wav
# audios/segments/silence_zoom_168.wav
# audios/segments/silence_zoom_169.wav
# audios/segments/silence_zoom_170.wav
# audios/segments/silence_zoom_171.wav
# audios/segments/silence_zoom_172.wav
# audios/segments/silence_zoom_173.wav
# audios/segments/silence_zoom_174.wav
# audios/segments/silence_zoom_175.wav
# audios/segments/silence_zoom_176.wav
# audios/segments/silence_zoom_177.wav
# audios/segments/silence_zoom_178.wav
# audios/segments/silence_zoom_179.wav
# audios/segments/silence_zoom_180.wav
# audios/segments/silence_zoom_181.wav
# audios/segments/silence_zoom_182.wav
# audios/segments/silence_zoom_183.wav
# audios/segments/silence_zoom_184.wav
# audios/segments/silence_zoom_185.wav
# audios/segments/silence_zoom_186.wav
# audios/segments/silence_zoom_187.wav
# audios/segments/silence_zoom_188.wav
# audios/segments/silence_zoom_189.wav
# audios/segments/silence_zoom_190.wav
# audios/segments/silence_zoom_191.wav
# audios/segments/silence_zoom_192.wav
# audios/segments/silence_zoom_193.wav
# audios/segments/silence_zoom_194.wav
# audios/segments/silence_zoom_195.wav
# audios/segments/silence_zoom_196.wav
# audios/segments/silence_zoom_197.wav
# audios/segments/silence_zoom_198.wav
# audios/segments/silence_zoom_199.wav
# audios/segments/silence_zoom_200.wav
# audios/segments/silence_zoom_201.wav
# audios/segments/silence_zoom_202.wav
# audios/segments/silence_zoom_203.wav
# audios/segments/silence_zoom_204.wav
# audios/segments/silence_zoom_205.wav
# audios/segments/silence_zoom_206.wav
# audios/segments/silence_zoom_207.wav
# audios/segments/silence_zoom_208.wav
# audios/segments/silence_zoom_209.wav
# audios/segments/silence_zoom_210.wav
# audios/segments/silence_zoom_211.wav
# audios/segments/silence_zoom_212.wav
# audios/segments/silence_zoom_213.wav
# audios/segments/silence_zoom_214.wav
# audios/segments/silence_zoom_215.wav
# audios/segments/silence_zoom_216.wav
# audios/segments/silence_zoom_217.wav
# audios/segments/silence_zoom_218.wav
# audios/segments/silence_zoom_219.wav
# audios/segments/silence_zoom_220.wav
# audios/segments/silence_zoom_221.wav
# audios/segments/silence_zoom_222.wav
# audios/segments/silence_zoom_223.wav
# audios/segments/silence_zoom_224.wav
# audios/segments/silence_zoom_225.wav
# audios/segments/silence_zoom_226.wav
# audios/segments/silence_zoom_227.wav
# audios/segments/silence_zoom_228.wav
# audios/segments/silence_zoom_229.wav
# audios/segments/silence_zoom_230.wav
# audios/segments/silence_zoom_231.wav
# audios/segments/silence_zoom_232.wav
# audios/segments/silence_zoom_233.wav
# audios/segments/silence_zoom_234.wav
# audios/segments/silence_zoom_235.wav
# audios/segments/silence_zoom_236.wav
# audios/segments/silence_zoom_237.wav
# audios/segments/silence_zoom_238.wav
# audios/segments/silence_zoom_239.wav
# audios/segments/silence_zoom_240.wav
# audios/segments/silence_zoom_241.wav
# audios/segments/silence_zoom_242.wav
# audios/segments/silence_zoom_243.wav
# audios/segments/silence_zoom_244.wav
# audios/segments/silence_zoom_245.wav
# audios/segments/silence_zoom_246.wav
# audios/segments/silence_zoom_247.wav
# audios/segments/silence_zoom_248.wav
# audios/segments/silence_zoom_249.wav
# audios/segments/silence_zoom_250.wav
# audios/segments/silence_zoom_251.wav
# audios/segments/silence_zoom_252.wav
# audios/segments/silence_zoom_253.wav
# audios/segments/silence_zoom_254.wav
# audios/segments/silence_zoom_255.wav
# audios/segments/silence_zoom_256.wav
# audios/segments/silence_zoom_257.wav
# audios/segments/silence_zoom_258.wav
# audios/segments/silence_zoom_259.wav
# audios/segments/silence_zoom_260.wav
# audios/segments/silence_zoom_261.wav
# audios/segments/silence_zoom_262.wav
# audios/segments/silence_zoom_263.wav
# audios/segments/silence_zoom_264.wav
# audios/segments/silence_zoom_265.wav
# audios/segments/silence_zoom_266.wav
# audios/segments/silence_zoom_267.wav
# audios/segments/silence_zoom_268.wav
# audios/segments/silence_zoom_269.wav
# audios/segments/silence_zoom_270.wav
# audios/segments/silence_zoom_271.wav
# audios/segments/silence_zoom_272.wav
# audios/segments/silence_zoom_273.wav
# audios/segments/silence_zoom_274.wav
# audios/segments/silence_zoom_275.wav
# audios/segments/silence_zoom_276.wav
# audios/segments/silence_zoom_277.wav
# audios/segments/silence_zoom_278.wav
# audios/segments/silence_zoom_279.wav
# audios/segments/silence_zoom_280.wav
# audios/segments/silence_zoom_281.wav
# audios/segments/silence_zoom_282.wav
# audios/segments/silence_zoom_283.wav
# audios/segments/silence_zoom_284.wav
# audios/segments/silence_zoom_285.wav
# audios/segments/silence_zoom_286.wav
# audios/segments/silence_zoom_287.wav
# audios/segments/silence_zoom_288.wav
# audios/segments/silence_zoom_289.wav
# audios/segments/silence_zoom_290.wav
# audios/segments/silence_zoom_291.wav
# audios/segments/silence_zoom_292.wav
# audios/segments/silence_zoom_293.wav
# audios/segments/silence_zoom_294.wav
# audios/segments/silence_zoom_295.wav
# audios/segments/silence_zoom_296.wav
# audios/segments/silence_zoom_297.wav
# audios/segments/silence_zoom_298.wav
# audios/segments/silence_zoom_299.wav
# audios/segments/silence_zoom_300.wav
# audios/segments/silence_zoom_301.wav
# audios/segments/silence_zoom_302.wav
# audios/segments/silence_zoom_303.wav
# audios/segments/silence_zoom_304.wav
# audios/segments/silence_zoom_305.wav
# audios/segments/silence_zoom_306.wav
# audios/segments/silence_zoom_307.wav
# audios/segments/silence_zoom_308.wav
# audios/segments/silence_zoom_309.wav
# audios/segments/silence_zoom_310.wav
# audios/segments/silence_zoom_311.wav
# audios/segments/silence_zoom_312.wav
# audios/segments/silence_zoom_313.wav
# audios/segments/silence_zoom_314.wav
# audios/segments/silence_zoom_315.wav
# audios/segments/silence_zoom_316.wav
# audios/segments/silence_zoom_317.wav
# audios/segments/silence_zoom_318.wav
# audios/segments/silence_zoom_319.wav
# audios/segments/silence_zoom_320.wav
# audios/segments/silence_zoom_321.wav
# audios/segments/silence_zoom_322.wav
# audios/segments/silence_zoom_323.wav
# audios/segments/silence_zoom_324.wav
# audios/segments/silence_zoom_325.wav
# audios/segments/silence_zoom_326.wav
# audios/segments/silence_zoom_327.wav
# audios/segments/silence_zoom_328.wav
# audios/segments/silence_zoom_329.wav
# audios/segments/silence_zoom_330.wav
# audios/segments/silence_zoom_331.wav
# audios/segments/silence_zoom_332.wav
# audios/segments/silence_zoom_333.wav
# audios/segments/silence_zoom_334.wav
# audios/segments/silence_zoom_335.wav
# audios/segments/silence_zoom_336.wav
# audios/segments/silence_zoom_337.wav
# audios/segments/silence_zoom_338.wav
# audios/segments/silence_zoom_339.wav
# audios/segments/silence_zoom_340.wav
# audios/segments/silence_zoom_341.wav
# audios/segments/silence_zoom_342.wav
# audios/segments/silence_zoom_343.wav
# audios/segments/silence_zoom_344.wav
# audios/segments/silence_zoom_345.wav
# audios/segments/silence_zoom_346.wav
# audios/segments/silence_zoom_347.wav
# audios/segments/silence_zoom_348.wav
# audios/segments/silence_zoom_349.wav
# audios/segments/silence_zoom_350.wav
# audios/segments/silence_zoom_351.wav
# audios/segments/silence_zoom_352.wav
# audios/segments/silence_zoom_353.wav
# audios/segments/silence_zoom_354.wav
# audios/segments/silence_zoom_355.wav
# audios/segments/silence_zoom_356.wav
# audios/segments/silence_zoom_357.wav
# audios/segments/silence_zoom_358.wav
# audios/segments/silence_zoom_359.wav
# audios/segments/silence_zoom_360.wav
# audios/segments/silence_zoom_361.wav
# audios/segments/silence_zoom_362.wav
# audios/segments/silence_zoom_363.wav
# audios/segments/silence_zoom_364.wav
# audios/segments/silence_zoom_365.wav
# audios/segments/silence_zoom_366.wav
# audios/segments/silence_zoom_367.wav
# audios/segments/silence_zoom_368.wav
# audios/segments/silence_zoom_369.wav
# audios/segments/silence_zoom_370.wav
# audios/segments/silence_zoom_371.wav
# audios/segments/silence_zoom_372.wav
# audios/segments/silence_zoom_373.wav
# audios/segments/silence_zoom_374.wav
# audios/segments/silence_zoom_375.wav
# audios/segments/silence_zoom_376.wav
# audios/segments/silence_zoom_377.wav
# audios/segments/silence_zoom_378.wav
# audios/segments/silence_zoom_379.wav
# audios/segments/silence_zoom_380.wav
# audios/segments/silence_zoom_381.wav
# audios/segments/silence_zoom_382.wav
# audios/segments/silence_zoom_383.wav
# audios/segments/silence_zoom_384.wav
# audios/segments/silence_zoom_385.wav
# audios/segments/silence_zoom_386.wav
# audios/segments/silence_zoom_387.wav
# audios/segments/silence_zoom_388.wav
# audios/segments/silence_zoom_389.wav
# audios/segments/silence_zoom_390.wav
# audios/segments/silence_zoom_391.wav
# audios/segments/silence_zoom_392.wav
# audios/segments/silence_zoom_393.wav
# audios/segments/silence_zoom_394.wav
# audios/segments/silence_zoom_395.wav
# audios/segments/silence_zoom_396.wav
# audios/segments/silence_zoom_397.wav
# audios/segments/silence_zoom_398.wav
# audios/segments/silence_zoom_399.wav
# audios/segments/silence_zoom_400.wav
# audios/segments/silence_zoom_401.wav
# audios/segments/silence_zoom_402.wav
# audios/segments/silence_zoom_403.wav
# audios/segments/silence_zoom_404.wav
# audios/segments/silence_zoom_405.wav
# audios/segments/silence_zoom_406.wav
# audios/segments/silence_zoom_407.wav
# audios/segments/silence_zoom_408.wav
# audios/segments/silence_zoom_409.wav
# audios/segments/silence_zoom_410.wav
# audios/segments/silence_zoom_411.wav
# audios/segments/silence_zoom_412.wav
# audios/segments/silence_zoom_413.wav
# audios/segments/silence_zoom_414.wav
# audios/segments/silence_zoom_415.wav
# audios/segments/silence_zoom_416.wav
# audios/segments/silence_zoom_417.wav
# audios/segments/silence_zoom_418.wav
# audios/segments/silence_zoom_419.wav
# audios/segments/silence_zoom_420.wav
# audios/segments/silence_zoom_421.wav
# audios/segments/silence_zoom_422.wav
# audios/segments/silence_zoom_423.wav
# audios/segments/silence_zoom_424.wav
# audios/segments/silence_zoom_425.wav
# audios/segments/silence_zoom_426.wav
# audios/segments/silence_zoom_427.wav
# audios/segments/silence_zoom_428.wav
# audios/segments/silence_zoom_429.wav
# audios/segments/silence_zoom_430.wav
# audios/segments/silence_zoom_431.wav
# audios/segments/silence_zoom_432.wav
# audios/segments/silence_zoom_433.wav
# audios/segments/silence_zoom_434.wav
# audios/segments/silence_zoom_435.wav
# audios/segments/silence_zoom_436.wav
# audios/segments/silence_zoom_437.wav
# audios/segments/silence_zoom_438.wav
# audios/segments/silence_zoom_439.wav
# audios/segments/silence_zoom_440.wav
# audios/segments/silence_zoom_441.wav
# audios/segments/silence_zoom_442.wav
# audios/segments/silence_zoom_443.wav
# audios/segments/silence_zoom_444.wav
# audios/segments/silence_zoom_445.wav
# audios/segments/silence_zoom_446.wav
# audios/segments/silence_zoom_447.wav
# audios/segments/silence_zoom_448.wav
# audios/segments/silence_zoom_449.wav
# audios/segments/silence_zoom_450.wav
# audios/segments/silence_zoom_451.wav
# audios/segments/silence_zoom_452.wav
# audios/segments/silence_zoom_453.wav
# audios/segments/silence_zoom_454.wav
# audios/segments/silence_zoom_455.wav
# audios/segments/silence_zoom_456.wav
# audios/segments/silence_zoom_457.wav
# audios/segments/silence_zoom_458.wav
# audios/segments/silence_zoom_459.wav
# audios/segments/silence_zoom_460.wav
# audios/segments/silence_zoom_461.wav
# audios/segments/silence_zoom_462.wav
# audios/segments/silence_zoom_463.wav
# audios/segments/silence_zoom_464.wav
# audios/segments/silence_zoom_465.wav
# audios/segments/silence_zoom_466.wav
# audios/segments/silence_zoom_467.wav
# audios/segments/silence_zoom_468.wav
# audios/segments/silence_zoom_469.wav
# audios/segments/silence_zoom_470.wav
# audios/segments/silence_zoom_471.wav
# audios/segments/silence_zoom_472.wav
# audios/segments/silence_zoom_473.wav
# audios/segments/silence_zoom_474.wav
# audios/segments/silence_zoom_475.wav
# audios/segments/silence_zoom_476.wav
# audios/segments/silence_zoom_477.wav
# audios/segments/silence_zoom_478.wav
# audios/segments/silence_zoom_479.wav
# audios/segments/silence_zoom_480.wav
# audios/segments/silence_zoom_481.wav
# audios/segments/silence_zoom_482.wav
# audios/segments/silence_zoom_483.wav
# audios/segments/silence_zoom_484.wav
# audios/segments/silence_zoom_485.wav
# audios/segments/silence_zoom_486.wav
# audios/segments/silence_zoom_487.wav
# audios/segments/silence_zoom_488.wav
# audios/segments/silence_zoom_489.wav
# audios/segments/silence_zoom_490.wav
# audios/segments/silence_zoom_491.wav
# audios/segments/silence_zoom_492.wav
# audios/segments/silence_zoom_493.wav
# audios/segments/silence_zoom_494.wav
# audios/segments/silence_zoom_495.wav
# audios/segments/silence_zoom_496.wav
# audios/segments/silence_zoom_497.wav
# audios/segments/silence_zoom_498.wav
# audios/segments/silence_zoom_499.wav
# audios/segments/silence_zoom_500.wav
# audios/segments/silence_zoom_501.wav
# audios/segments/silence_zoom_502.wav
# audios/segments/silence_zoom_503.wav
# audios/segments/silence_zoom_504.wav
# audios/segments/silence_zoom_505.wav
# audios/segments/silence_zoom_506.wav
# audios/segments/silence_zoom_507.wav
# audios/segments/silence_zoom_508.wav
# audios/segments/silence_zoom_509.wav
# audios/segments/silence_zoom_510.wav
# audios/segments/silence_zoom_511.wav
# audios/segments/silence_zoom_512.wav
# audios/segments/silence_zoom_513.wav
# audios/segments/silence_zoom_514.wav
# audios/segments/silence_zoom_515.wav
# audios/segments/silence_zoom_516.wav
# audios/segments/silence_zoom_517.wav
# audios/segments/silence_zoom_518.wav
# audios/segments/silence_zoom_519.wav
# audios/segments/silence_zoom_520.wav
# audios/segments/silence_zoom_521.wav
# audios/segments/silence_zoom_522.wav
# audios/segments/silence_zoom_523.wav
# audios/segments/silence_zoom_524.wav
# audios/segments/silence_zoom_525.wav
# audios/segments/silence_zoom_526.wav
# audios/segments/silence_zoom_527.wav
# audios/segments/silence_zoom_528.wav
# audios/segments/silence_zoom_529.wav
# audios/segments/silence_zoom_530.wav
# audios/segments/silence_zoom_531.wav
# audios/segments/silence_zoom_532.wav
# audios/segments/silence_zoom_533.wav
# audios/segments/silence_zoom_534.wav
# audios/segments/silence_zoom_535.wav
# audios/segments/silence_zoom_536.wav
# audios/segments/silence_zoom_537.wav
# audios/segments/silence_zoom_538.wav
# audios/segments/silence_zoom_539.wav
# audios/segments/silence_zoom_540.wav
# audios/segments/silence_zoom_541.wav
# audios/segments/silence_zoom_542.wav
# audios/segments/silence_zoom_543.wav
# audios/segments/silence_zoom_544.wav
# audios/segments/silence_zoom_545.wav
# audios/segments/silence_zoom_546.wav
# audios/segments/silence_zoom_547.wav
# audios/segments/silence_zoom_548.wav
# audios/segments/silence_zoom_549.wav
# audios/segments/silence_zoom_550.wav
# audios/segments/silence_zoom_551.wav
# audios/segments/silence_zoom_552.wav
# audios/segments/silence_zoom_553.wav
# audios/segments/silence_zoom_554.wav
# audios/segments/silence_zoom_555.wav
# audios/segments/silence_zoom_556.wav
# audios/segments/silence_zoom_557.wav
# audios/segments/silence_zoom_558.wav
# audios/segments/silence_zoom_559.wav
# audios/segments/silence_zoom_560.wav
# audios/segments/silence_zoom_561.wav
# audios/segments/silence_zoom_562.wav
# audios/segments/silence_zoom_563.wav
# audios/segments/silence_zoom_564.wav
# audios/segments/silence_zoom_565.wav
# audios/segments/silence_zoom_566.wav
# audios/segments/silence_zoom_567.wav
# audios/segments/silence_zoom_568.wav
# audios/segments/silence_zoom_569.wav
# audios/segments/silence_zoom_570.wav
# audios/segments/silence_zoom_571.wav
# audios/segments/silence_zoom_572.wav
# audios/segments/silence_zoom_573.wav
# audios/segments/silence_zoom_574.wav
# audios/segments/silence_zoom_575.wav
# audios/segments/silence_zoom_576.wav
# audios/segments/silence_zoom_577.wav
# audios/segments/silence_zoom_578.wav
# audios/segments/silence_zoom_579.wav
# audios/segments/silence_zoom_580.wav
# audios/segments/silence_zoom_581.wav
# audios/segments/silence_zoom_582.wav
# audios/segments/silence_zoom_583.wav
# audios/segments/silence_zoom_584.wav
# audios/segments/silence_zoom_585.wav
# audios/segments/silence_zoom_586.wav
# audios/segments/silence_zoom_587.wav
# audios/segments/silence_zoom_588.wav
# audios/segments/silence_zoom_589.wav
# audios/segments/silence_zoom_590.wav
# audios/segments/silence_zoom_591.wav
# audios/segments/silence_zoom_592.wav
# audios/segments/silence_zoom_593.wav
# audios/segments/silence_zoom_594.wav
# audios/segments/silence_zoom_595.wav
# audios/segments/silence_zoom_596.wav
# audios/segments/silence_zoom_597.wav
# audios/segments/silence_zoom_598.wav
# audios/segments/silence_zoom_599.wav
# audios/segments/silence_zoom_600.wav
# audios/segments/silence_zoom_601.wav
# audios/segments/silence_zoom_602.wav
# audios/segments/silence_zoom_603.wav
# audios/segments/silence_zoom_604.wav
# audios/segments/silence_zoom_605.wav
# audios/segments/silence_zoom_606.wav
# audios/segments/silence_zoom_607.wav
# audios/segments/silence_zoom_608.wav
# audios/segments/silence_zoom_609.wav
# audios/segments/silence_zoom_610.wav
# audios/segments/silence_zoom_611.wav
# audios/segments/silence_zoom_612.wav
# audios/segments/silence_zoom_613.wav
# audios/segments/silence_zoom_614.wav
# audios/segments/silence_zoom_615.wav
# audios/segments/silence_zoom_616.wav
# audios/segments/silence_zoom_617.wav
# audios/segments/silence_zoom_618.wav
# audios/segments/silence_zoom_619.wav
# audios/segments/silence_zoom_620.wav
# audios/segments/silence_zoom_621.wav
# audios/segments/silence_zoom_622.wav
# audios/segments/silence_zoom_623.wav
# audios/segments/silence_zoom_624.wav
# audios/segments/silence_zoom_625.wav
# audios/segments/silence_zoom_626.wav
# audios/segments/silence_zoom_627.wav
# audios/segments/silence_zoom_628.wav
# audios/segments/silence_zoom_629.wav
# audios/segments/silence_zoom_630.wav
# audios/segments/silence_zoom_631.wav
# audios/segments/silence_zoom_632.wav
# audios/segments/silence_zoom_633.wav
# audios/segments/silence_zoom_634.wav
# audios/segments/silence_zoom_635.wav
# audios/segments/silence_zoom_636.wav
# audios/segments/silence_zoom_637.wav
# audios/segments/silence_zoom_638.wav
# audios/segments/silence_zoom_639.wav
# audios/segments/silence_zoom_640.wav
# audios/segments/silence_zoom_641.wav
# audios/segments/silence_zoom_642.wav
# audios/segments/silence_zoom_643.wav
# audios/segments/silence_zoom_644.wav
# audios/segments/silence_zoom_645.wav
# audios/segments/silence_zoom_646.wav
# audios/segments/silence_zoom_647.wav
# audios/segments/silence_zoom_648.wav
# audios/segments/silence_zoom_649.wav
# audios/segments/silence_zoom_650.wav
# audios/segments/silence_zoom_651.wav
# audios/segments/silence_zoom_652.wav
# audios/segments/silence_zoom_653.wav
# audios/segments/silence_zoom_654.wav
# audios/segments/silence_zoom_655.wav
# audios/segments/silence_zoom_656.wav
# audios/segments/silence_zoom_657.wav
# audios/segments/silence_zoom_658.wav
# audios/segments/silence_zoom_659.wav
# audios/segments/silence_zoom_660.wav
# audios/segments/silence_zoom_661.wav
# audios/segments/silence_zoom_662.wav
# audios/segments/silence_zoom_663.wav
# audios/segments/silence_zoom_664.wav
# audios/segments/silence_zoom_665.wav
# audios/segments/silence_zoom_666.wav
# audios/segments/silence_zoom_667.wav
# audios/segments/silence_zoom_668.wav
# audios/segments/silence_zoom_669.wav
# audios/segments/silence_zoom_670.wav
# audios/segments/silence_zoom_671.wav
# audios/segments/silence_zoom_672.wav
# audios/segments/silence_zoom_673.wav
# audios/segments/silence_zoom_674.wav
# audios/segments/silence_zoom_675.wav
# audios/segments/silence_zoom_676.wav
# audios/segments/silence_zoom_677.wav
# audios/segments/silence_zoom_678.wav
# audios/segments/silence_zoom_679.wav
# audios/segments/silence_zoom_680.wav
# audios/segments/silence_zoom_681.wav
# audios/segments/silence_zoom_682.wav
# audios/segments/silence_zoom_683.wav
# audios/segments/silence_zoom_684.wav
# audios/segments/silence_zoom_685.wav
# audios/segments/silence_zoom_686.wav
# audios/segments/silence_zoom_687.wav
# audios/segments/silence_zoom_688.wav
# audios/segments/silence_zoom_689.wav
# audios/segments/silence_zoom_690.wav
# audios/segments/silence_zoom_691.wav
# audios/segments/silence_zoom_692.wav
# audios/segments/silence_zoom_693.wav
# audios/segments/silence_zoom_694.wav
# audios/segments/silence_zoom_695.wav
# ...
# audios/segments/cooling_201.wav
# audios/segments/cooling_202.wav
# audios/segments/cooling_203.wav
# audios/segments/cooling_204.wav
# audios/segments/cooling_205.wav
# audios/segments/cooling_206.wav
# audios/segments/cooling_207.wav
# audios/segments/cooling_208.wav
# audios/segments/cooling_209.wav
# audios/segments/cooling_210.wav
# audios/segments/cooling_211.wav
# audios/segments/cooling_212.wav
# audios/segments/cooling_213.wav
# audios/segments/cooling_214.wav
# audios/segments/cooling_215.wav
# audios/segments/cooling_216.wav
# audios/segments/cooling_217.wav
# audios/segments/cooling_218.wav
# audios/segments/cooling_219.wav
# audios/segments/cooling_220.wav
# audios/segments/cooling_221.wav
# audios/segments/cooling_222.wav
# audios/segments/cooling_223.wav
# audios/segments/cooling_224.wav
# audios/segments/cooling_225.wav
# audios/segments/cooling_226.wav
# audios/segments/cooling_227.wav
# audios/segments/cooling_228.wav
# audios/segments/cooling_229.wav
# audios/segments/cooling_230.wav
# audios/segments/cooling_231.wav
# audios/segments/cooling_232.wav
# audios/segments/cooling_233.wav
# audios/segments/cooling_234.wav
# audios/segments/cooling_235.wav
# audios/segments/cooling_236.wav
# audios/segments/cooling_237.wav
# audios/segments/cooling_238.wav
# audios/segments/cooling_239.wav
# audios/segments/cooling_240.wav
# audios/segments/cooling_241.wav
# audios/segments/cooling_242.wav
# audios/segments/cooling_243.wav
# audios/segments/cooling_244.wav
# audios/segments/cooling_245.wav
# audios/segments/cooling_246.wav
# audios/segments/cooling_247.wav
# audios/segments/cooling_248.wav
# audios/segments/cooling_249.wav
# audios/segments/cooling_250.wav
# audios/segments/cooling_251.wav
# audios/segments/cooling_252.wav
# audios/segments/cooling_253.wav
# audios/segments/cooling_254.wav
# audios/segments/cooling_255.wav
# audios/segments/cooling_256.wav
# audios/segments/cooling_257.wav
# audios/segments/cooling_258.wav
# audios/segments/cooling_259.wav
# audios/segments/cooling_260.wav
# audios/segments/cooling_261.wav
# audios/segments/cooling_262.wav
# audios/segments/cooling_263.wav
# audios/segments/cooling_264.wav
# audios/segments/cooling_265.wav
# audios/segments/cooling_266.wav
# audios/segments/cooling_267.wav
# audios/segments/cooling_268.wav
# audios/segments/cooling_269.wav
# audios/segments/cooling_270.wav
# audios/segments/cooling_271.wav
# audios/segments/cooling_272.wav
# audios/segments/cooling_273.wav
# audios/segments/cooling_274.wav
# audios/segments/cooling_275.wav
# audios/segments/cooling_276.wav
# audios/segments/cooling_277.wav
# audios/segments/cooling_278.wav
# audios/segments/cooling_279.wav
# audios/segments/cooling_280.wav
# audios/segments/cooling_281.wav
# audios/segments/cooling_282.wav
# audios/segments/cooling_283.wav
# audios/segments/cooling_284.wav
# audios/segments/cooling_285.wav
# audios/segments/cooling_286.wav
# audios/segments/cooling_287.wav
# audios/segments/cooling_288.wav
# audios/segments/cooling_289.wav
# audios/segments/cooling_290.wav
# audios/segments/cooling_291.wav
# audios/segments/cooling_292.wav
# audios/segments/cooling_293.wav
# audios/segments/cooling_294.wav
# audios/segments/cooling_295.wav
# audios/segments/cooling_296.wav
# audios/segments/cooling_297.wav
# audios/segments/cooling_298.wav
# audios/segments/cooling_299.wav
# audios/segments/cooling_300.wav
# audios/segments/cooling_301.wav
# audios/segments/cooling_302.wav
# audios/segments/cooling_303.wav
# audios/segments/cooling_304.wav
# audios/segments/cooling_305.wav
# audios/segments/cooling_306.wav
# audios/segments/cooling_307.wav
# audios/segments/cooling_308.wav
# audios/segments/cooling_309.wav
# audios/segments/cooling_310.wav
# audios/segments/cooling_311.wav
# audios/segments/cooling_312.wav
# audios/segments/cooling_313.wav
# audios/segments/cooling_314.wav
# audios/segments/cooling_315.wav
# audios/segments/cooling_316.wav
# audios/segments/cooling_317.wav
# audios/segments/cooling_318.wav
# audios/segments/cooling_319.wav
# audios/segments/cooling_320.wav
# audios/segments/cooling_321.wav
# audios/segments/cooling_322.wav
# audios/segments/cooling_323.wav
# audios/segments/cooling_324.wav
# audios/segments/cooling_325.wav
# audios/segments/cooling_326.wav
# audios/segments/cooling_327.wav
# audios/segments/cooling_328.wav
# audios/segments/cooling_329.wav
# audios/segments/cooling_330.wav
# audios/segments/cooling_331.wav
# audios/segments/cooling_332.wav
# audios/segments/cooling_333.wav
# audios/segments/cooling_334.wav
# audios/segments/cooling_335.wav
# audios/segments/cooling_336.wav
# audios/segments/cooling_337.wav
# audios/segments/cooling_338.wav
# audios/segments/cooling_339.wav
# audios/segments/cooling_340.wav
# audios/segments/cooling_341.wav
# audios/segments/cooling_342.wav
# audios/segments/cooling_343.wav
# audios/segments/cooling_344.wav
# audios/segments/cooling_345.wav
# audios/segments/cooling_346.wav
# audios/segments/cooling_347.wav
# audios/segments/cooling_348.wav
# audios/segments/cooling_349.wav
# audios/segments/cooling_350.wav
# audios/segments/cooling_351.wav
# audios/segments/cooling_352.wav
# audios/segments/cooling_353.wav
# audios/segments/cooling_354.wav
# audios/segments/cooling_355.wav
# audios/segments/cooling_356.wav
# audios/segments/cooling_357.wav
# audios/segments/cooling_358.wav
# audios/segments/cooling_359.wav
# audios/segments/cooling_360.wav
# audios/segments/cooling_361.wav
# audios/segments/cooling_362.wav
# audios/segments/cooling_363.wav
# audios/segments/cooling_364.wav
# audios/segments/cooling_365.wav
# audios/segments/cooling_366.wav
# audios/segments/cooling_367.wav
# audios/segments/cooling_368.wav
# audios/segments/cooling_369.wav
# audios/segments/cooling_370.wav
# audios/segments/cooling_371.wav
# audios/segments/cooling_372.wav
# audios/segments/cooling_373.wav
# audios/segments/cooling_374.wav
# audios/segments/cooling_375.wav
# audios/segments/cooling_376.wav
# audios/segments/cooling_377.wav
# audios/segments/cooling_378.wav
# audios/segments/cooling_379.wav
# audios/segments/cooling_380.wav
# audios/segments/cooling_381.wav
# audios/segments/cooling_382.wav
# audios/segments/cooling_383.wav
# audios/segments/cooling_384.wav
# audios/segments/cooling_385.wav
# audios/segments/cooling_386.wav
# audios/segments/cooling_387.wav
# audios/segments/cooling_388.wav
# audios/segments/cooling_389.wav
# audios/segments/cooling_390.wav
# audios/segments/cooling_391.wav
# audios/segments/cooling_392.wav
# audios/segments/cooling_393.wav
# audios/segments/cooling_394.wav
# audios/segments/cooling_395.wav
# audios/segments/cooling_396.wav
# audios/segments/cooling_397.wav
# audios/segments/cooling_398.wav
# audios/segments/cooling_399.wav
# audios/segments/cooling_400.wav
# audios/segments/cooling_401.wav
# audios/segments/cooling_402.wav
# audios/segments/cooling_403.wav
# audios/segments/cooling_404.wav
# audios/segments/cooling_405.wav
# audios/segments/cooling_406.wav
# audios/segments/cooling_407.wav
# audios/segments/cooling_408.wav
# audios/segments/cooling_409.wav
# audios/segments/cooling_410.wav
# audios/segments/cooling_411.wav
# audios/segments/cooling_412.wav
# audios/segments/cooling_413.wav
# audios/segments/cooling_414.wav
# audios/segments/cooling_415.wav
# audios/segments/cooling_416.wav
# audios/segments/cooling_417.wav
# audios/segments/cooling_418.wav
# audios/segments/cooling_419.wav
# audios/segments/cooling_420.wav
# audios/segments/cooling_421.wav
# audios/segments/cooling_422.wav
# audios/segments/cooling_423.wav
# audios/segments/cooling_424.wav
# audios/segments/cooling_425.wav
# audios/segments/cooling_426.wav
# audios/segments/cooling_427.wav
# audios/segments/cooling_428.wav
# audios/segments/cooling_429.wav
# audios/segments/cooling_430.wav
# audios/segments/cooling_431.wav
# audios/segments/cooling_432.wav
# audios/segments/cooling_433.wav
# audios/segments/cooling_434.wav
# audios/segments/cooling_435.wav
# audios/segments/cooling_436.wav
# audios/segments/cooling_437.wav
# audios/segments/cooling_438.wav
# audios/segments/cooling_439.wav
# audios/segments/cooling_440.wav
# audios/segments/cooling_441.wav
# audios/segments/cooling_442.wav
# audios/segments/cooling_443.wav
# audios/segments/cooling_444.wav
# audios/segments/cooling_445.wav
# audios/segments/cooling_446.wav
# audios/segments/cooling_447.wav
# audios/segments/cooling_448.wav
# audios/segments/cooling_449.wav
# audios/segments/cooling_450.wav
# audios/segments/cooling_451.wav
# audios/segments/cooling_452.wav
# audios/segments/cooling_453.wav
# audios/segments/cooling_454.wav
# audios/segments/cooling_455.wav
# audios/segments/cooling_456.wav
# audios/segments/cooling_457.wav
# audios/segments/cooling_458.wav
# audios/segments/cooling_459.wav
# audios/segments/cooling_460.wav
# audios/segments/cooling_461.wav
# audios/segments/cooling_462.wav
# audios/segments/cooling_463.wav
# audios/segments/cooling_464.wav
# audios/segments/cooling_465.wav
# audios/segments/cooling_466.wav
# audios/segments/cooling_467.wav
# audios/segments/cooling_468.wav
# audios/segments/cooling_469.wav
# audios/segments/cooling_470.wav
# audios/segments/cooling_471.wav
# audios/segments/cooling_472.wav
# audios/segments/cooling_473.wav
# audios/segments/cooling_474.wav
# audios/segments/cooling_475.wav
# audios/segments/cooling_476.wav
# audios/segments/cooling_477.wav
# audios/segments/cooling_478.wav
# audios/segments/cooling_479.wav
# audios/segments/cooling_480.wav
# audios/segments/cooling_481.wav
# audios/segments/cooling_482.wav
# audios/segments/cooling_483.wav
# audios/segments/cooling_484.wav
# audios/segments/cooling_485.wav
# audios/segments/cooling_486.wav
# audios/segments/cooling_487.wav
# audios/segments/cooling_488.wav
# audios/segments/cooling_489.wav
# audios/segments/cooling_490.wav
# audios/segments/cooling_491.wav
# audios/segments/cooling_492.wav
# audios/segments/cooling_493.wav
# audios/segments/cooling_494.wav
# audios/segments/cooling_495.wav
# audios/segments/cooling_496.wav
# audios/segments/cooling_497.wav
# audios/segments/cooling_498.wav
# audios/segments/cooling_499.wav
# audios/segments/cooling_500.wav
# audios/segments/cooling_501.wav
# audios/segments/cooling_502.wav
# audios/segments/cooling_503.wav
# audios/segments/cooling_504.wav
# audios/segments/cooling_505.wav
# audios/segments/cooling_506.wav
# audios/segments/cooling_507.wav
# audios/segments/cooling_508.wav
# audios/segments/cooling_509.wav
# audios/segments/cooling_510.wav
# audios/segments/cooling_511.wav
# audios/segments/cooling_512.wav
# audios/segments/cooling_513.wav
# audios/segments/cooling_514.wav
# audios/segments/cooling_515.wav
# audios/segments/cooling_516.wav
# audios/segments/cooling_517.wav
# audios/segments/cooling_518.wav
# audios/segments/cooling_519.wav
# audios/segments/cooling_520.wav
# audios/segments/cooling_521.wav
# audios/segments/cooling_522.wav
# audios/segments/cooling_523.wav
# audios/segments/cooling_524.wav
# audios/segments/cooling_525.wav
# audios/segments/cooling_526.wav
# audios/segments/cooling_527.wav
# audios/segments/cooling_528.wav
# audios/segments/cooling_529.wav
# audios/segments/cooling_530.wav
# audios/segments/cooling_531.wav
# audios/segments/cooling_532.wav
# audios/segments/cooling_533.wav
# audios/segments/cooling_534.wav
# audios/segments/cooling_535.wav
# audios/segments/cooling_536.wav
# audios/segments/cooling_537.wav
# audios/segments/cooling_538.wav
# audios/segments/cooling_539.wav
# audios/segments/cooling_540.wav
# audios/segments/cooling_541.wav
# audios/segments/cooling_542.wav
# audios/segments/cooling_543.wav
# audios/segments/cooling_544.wav
# audios/segments/cooling_545.wav
# audios/segments/cooling_546.wav
# audios/segments/cooling_547.wav
# audios/segments/cooling_548.wav
# audios/segments/cooling_549.wav
# audios/segments/cooling_550.wav
# audios/segments/cooling_551.wav
# audios/segments/cooling_552.wav
# audios/segments/cooling_553.wav
# audios/segments/cooling_554.wav
# audios/segments/cooling_555.wav
# audios/segments/cooling_556.wav
# audios/segments/cooling_557.wav
# audios/segments/cooling_558.wav
# audios/segments/cooling_559.wav
# audios/segments/cooling_560.wav
# audios/segments/cooling_561.wav
# audios/segments/cooling_562.wav
# audios/segments/cooling_563.wav
# audios/segments/cooling_564.wav
# audios/segments/cooling_565.wav
# audios/segments/cooling_566.wav
# audios/segments/cooling_567.wav
# audios/segments/cooling_568.wav
# audios/segments/cooling_569.wav
# audios/segments/cooling_570.wav
# audios/segments/cooling_571.wav
# audios/segments/cooling_572.wav
# audios/segments/cooling_573.wav
# audios/segments/cooling_574.wav
# audios/segments/cooling_575.wav
# audios/segments/cooling_576.wav
# audios/segments/cooling_577.wav
# audios/segments/cooling_578.wav
# audios/segments/cooling_579.wav
# audios/segments/cooling_580.wav
# audios/segments/cooling_581.wav
# audios/segments/cooling_582.wav
# audios/segments/cooling_583.wav
# audios/segments/cooling_584.wav
# audios/segments/cooling_585.wav
# audios/segments/cooling_586.wav
# audios/segments/cooling_587.wav
# audios/segments/cooling_588.wav
# audios/segments/cooling_589.wav
# audios/segments/cooling_590.wav
# audios/segments/cooling_591.wav
# audios/segments/cooling_592.wav
# audios/segments/cooling_593.wav
# audios/segments/cooling_594.wav
# audios/segments/cooling_595.wav
# audios/segments/cooling_596.wav
# audios/segments/cooling_597.wav
# audios/segments/cooling_598.wav
# audios/segments/cooling_599.wav
# audios/segments/cooling_600.wav
# audios/segments/cooling_601.wav
# audios/segments/cooling_602.wav
# audios/segments/cooling_603.wav
# audios/segments/cooling_604.wav
# audios/segments/cooling_605.wav
# audios/segments/cooling_606.wav
# audios/segments/cooling_607.wav
# audios/segments/cooling_608.wav
# audios/segments/cooling_609.wav
# audios/segments/cooling_610.wav
# audios/segments/cooling_611.wav
# audios/segments/cooling_612.wav
# audios/segments/cooling_613.wav
# audios/segments/cooling_614.wav
# audios/segments/cooling_615.wav
# audios/segments/cooling_616.wav
# audios/segments/cooling_617.wav
# audios/segments/cooling_618.wav
# audios/segments/cooling_619.wav
# audios/segments/cooling_620.wav
# audios/segments/cooling_621.wav
# audios/segments/cooling_622.wav
# audios/segments/cooling_623.wav
# audios/segments/cooling_624.wav
# audios/segments/cooling_625.wav
# audios/segments/cooling_626.wav
# audios/segments/cooling_627.wav
# audios/segments/cooling_628.wav
# audios/segments/cooling_629.wav
# audios/segments/cooling_630.wav
# audios/segments/cooling_631.wav
# audios/segments/cooling_632.wav
# audios/segments/cooling_633.wav
# audios/segments/cooling_634.wav
# audios/segments/cooling_635.wav
# audios/segments/cooling_636.wav
# audios/segments/cooling_637.wav
# audios/segments/cooling_638.wav
# audios/segments/cooling_639.wav
# audios/segments/cooling_640.wav
# audios/segments/cooling_641.wav
# audios/segments/cooling_642.wav
# audios/segments/cooling_643.wav
# audios/segments/cooling_644.wav
# audios/segments/cooling_645.wav
# audios/segments/cooling_646.wav
# audios/segments/cooling_647.wav
# audios/segments/cooling_648.wav
# audios/segments/cooling_649.wav
# audios/segments/cooling_650.wav
# audios/segments/cooling_651.wav
# audios/segments/cooling_652.wav
# audios/segments/cooling_653.wav
# audios/segments/cooling_654.wav
# audios/segments/cooling_655.wav
# audios/segments/cooling_656.wav
# audios/segments/cooling_657.wav
# audios/segments/cooling_658.wav
# audios/segments/cooling_659.wav
# audios/segments/cooling_660.wav
# audios/segments/cooling_661.wav
# audios/segments/cooling_662.wav
# audios/segments/cooling_663.wav
# audios/segments/cooling_664.wav
# audios/segments/cooling_665.wav
# audios/segments/cooling_666.wav
# audios/segments/cooling_667.wav
# audios/segments/cooling_668.wav
# audios/segments/cooling_669.wav
# audios/segments/cooling_670.wav
# audios/segments/cooling_671.wav
# audios/segments/cooling_672.wav
# audios/segments/cooling_673.wav
# audios/segments/cooling_674.wav
# audios/segments/cooling_675.wav
# audios/segments/cooling_676.wav
# audios/segments/cooling_677.wav
# audios/segments/cooling_678.wav
# audios/segments/cooling_679.wav
# audios/segments/cooling_680.wav
# audios/segments/cooling_681.wav
# audios/segments/cooling_682.wav
# audios/segments/cooling_683.wav
# audios/segments/cooling_684.wav
# audios/segments/cooling_685.wav
# audios/segments/cooling_686.wav
# audios/segments/cooling_687.wav
# audios/segments/cooling_688.wav
# audios/segments/cooling_689.wav
# audios/segments/cooling_690.wav
# audios/segments/cooling_691.wav
# audios/segments/cooling_692.wav
# audios/segments/cooling_693.wav
# audios/segments/cooling_694.wav
# audios/segments/cooling_695.wav
# audios/segments/cooling_696.wav
# audios/segments/cooling_697.wav
# audios/segments/cooling_698.wav
# audios/segments/cooling_699.wav
# 3756 segment files created

# %%
#If required, you can use this cell to delete all files in a given folder
def delete_files_in_dir(dir_name):
    '''Deleting all files in a directory
    '''
    for root, dirs, files in os.walk(dir_name):
        for file in files:
            file_name = os.path.join(root,file)
            os.remove(file_name);print(file_name, 'removed');

#delete_files_in_dir(segments_dir)

# %% [markdown]
# Segments saved into separate files. Check the "audios/segments/" folder.
#
# ## Feature extraction
#
# Let's compute a list of common features for each of the files and form a data frame including features and categories. We will be using the [FreesoundExtractor function of Essentia](https://essentia.upf.edu/freesound_extractor.html#configuration) which is a feature extractor for sound analysis which suits perfeclty in our line of research.
#
# Let's first run it for a file and check its output:

# %%
import essentia.standard as es

#Running music extractor for a file:
file = segment_files[0]#simply pick the first file in the list
features, features_frames = es.FreesoundExtractor(lowlevelSilentFrames='drop',
                                                  lowlevelFrameSize = 2048,
                                                  lowlevelHopSize = 1024,
                                                  lowlevelStats = ['mean', 'stdev'])(file)
features_validation, features_frames_validation = es.FreesoundExtractor(lowlevelSilentFrames='drop',
                                                  lowlevelFrameSize = 2048,
                                                  lowlevelHopSize = 1024,
                                                  lowlevelStats = ['mean', 'stdev'])(file)

# %% [markdown]
# Essentia-MusicExtractor extracts a large number of features. As we want our model to work in real-time, our goal will be to obtain a the best classification accuracy that we can, using the less descriptors the better, as the computation will be less demanding.

# %%
scalar_lowlevel_descriptors = [descriptor for descriptor in features.descriptorNames() if ('lowlevel.spectral_centroid.mean' in descriptor) or ('lowlevel.spectral_spread.mean' in descriptor) and isinstance(features[descriptor], float)]
print("Subset of features to be considered:\n",scalar_lowlevel_descriptors)
num_of_descriptors = len(scalar_lowlevel_descriptors)
print(num_of_descriptors)#Number of chosen descriptors
# Out:
# Subset of features to be considered:
#  ['lowlevel.spectral_centroid.mean', 'lowlevel.spectral_spread.mean']
# 2

# %% [markdown]
# Running FreesoundExtractor for all files, keeping the selected subset of features, writing to an output file: data.csv
#
# In this case, we will create a data csv file for both the train and validation sets just to make sure that we can choose which information goes to each of the two. We apply an _if_ condition to put in each file the features of the samples that we need in each of the specific experiments.

# %%
# Extracting features and writing in data_file.csv file in the segments folder
# Each line in the data_file.csv file represents a sample with features and the class information as the last element
data_file_train = os.path.join(segments_dir,'data_train.csv')
data_file_validation = os.path.join(segments_dir,'data_validation.csv')
file_count = 0
with open(data_file_train, 'w') as writer:
    #adding column names as the first line in csv
    line2write = ','.join(scalar_lowlevel_descriptors + ['state']).replace('lowlevel.','') + '\n'
    writer.write(line2write)
    for file in segment_files:
        if '.wav' and not 'zoom' in file:
            file_count +=1
            if file_count % 20 == 0:#print name of a file every 20 files
                print(file_count, "files processed, current file: ",file)
            features, features_frames = es.MusicExtractor(lowlevelSilentFrames='drop',
                                                          lowlevelFrameSize = 2048,
                                                          lowlevelHopSize = 1024,
                                                          lowlevelStats = ['mean', 'stdev'])(file)
            selected_features = [features[descriptor] for descriptor in scalar_lowlevel_descriptors]
            state = file.split('/')[-1].split('_')[0].lower()#class information
            line2write = str(selected_features)[1:-1] + ',' + state + '\n'
            writer.write(line2write)
with open(data_file_validation, 'w') as writer:
    #adding column names as the first line in csv
    line2write = ','.join(scalar_lowlevel_descriptors + ['state']).replace('lowlevel.','') + '\n'
    writer.write(line2write)
    for file in segment_files:
        if '.wav' and 'zoom' in file:
            file_count +=1
            if file_count % 20 == 0:#print name of a file every 20 files
                print(file_count, "files processed, current file: ",file)
            features_validation, features_frames_validation = es.MusicExtractor(lowlevelSilentFrames='drop',
                                                          lowlevelFrameSize = 2048,
                                                          lowlevelHopSize = 1024,
                                                          lowlevelStats = ['mean', 'stdev'])(file)
            selected_features_validation = [features_validation[descriptor] for descriptor in scalar_lowlevel_descriptors]
            state = file.split('/')[-1].split('_')[0].lower() #class information
            line2write = str(selected_features_validation)[1:-1] + ',' + state + '\n'
            writer.write(line2write)
            
print("A total of ",file_count, "files processed")
print(selected_features)
# Out:
# 20 files processed, current file:  audios/segments/silence_19.wav
# 40 files processed, current file:  audios/segments/silence_39.wav
# 60 files processed, current file:  audios/segments/silence_59.wav
# 80 files processed, current file:  audios/segments/silence_79.wav
# 100 files processed, current file:  audios/segments/silence_99.wav
# 120 files processed, current file:  audios/segments/silence_119.wav
# 140 files processed, current file:  audios/segments/silence_139.wav
# 160 files processed, current file:  audios/segments/silence_159.wav
# 180 files processed, current file:  audios/segments/silence_179.wav
# 200 files processed, current file:  audios/segments/silence_199.wav
# 220 files processed, current file:  audios/segments/silence_219.wav
# 240 files processed, current file:  audios/segments/silence_239.wav
# 260 files processed, current file:  audios/segments/silence_259.wav
# 280 files processed, current file:  audios/segments/silence_279.wav
# 300 files processed, current file:  audios/segments/silence_299.wav
# 320 files processed, current file:  audios/segments/silence_319.wav
# 340 files processed, current file:  audios/segments/silence_339.wav
# 360 files processed, current file:  audios/segments/silence_359.wav
# 380 files processed, current file:  audios/segments/silence_379.wav
# 400 files processed, current file:  audios/segments/silence_399.wav
# 420 files processed, current file:  audios/segments/silence_419.wav
# 440 files processed, current file:  audios/segments/silence_439.wav
# 460 files processed, current file:  audios/segments/silence_459.wav
# 480 files processed, current file:  audios/segments/silence_479.wav
# 500 files processed, current file:  audios/segments/silence_499.wav
# 520 files processed, current file:  audios/segments/silence_519.wav
# 540 files processed, current file:  audios/segments/silence_539.wav
# 560 files processed, current file:  audios/segments/silence_559.wav
# 580 files processed, current file:  audios/segments/silence_579.wav
# 600 files processed, current file:  audios/segments/silence_599.wav
# 620 files processed, current file:  audios/segments/silence_619.wav
# 640 files processed, current file:  audios/segments/silence_639.wav
# 660 files processed, current file:  audios/segments/silence_659.wav
# 680 files processed, current file:  audios/segments/silence_679.wav
# 700 files processed, current file:  audios/segments/silence_699.wav
# 720 files processed, current file:  audios/segments/working_19.wav
# 740 files processed, current file:  audios/segments/working_39.wav
# 760 files processed, current file:  audios/segments/working_59.wav
# 780 files processed, current file:  audios/segments/working_79.wav
# 800 files processed, current file:  audios/segments/working_99.wav
# 820 files processed, current file:  audios/segments/working_119.wav
# 840 files processed, current file:  audios/segments/working_139.wav
# 860 files processed, current file:  audios/segments/working_159.wav
# 880 files processed, current file:  audios/segments/working_179.wav
# 900 files processed, current file:  audios/segments/working_199.wav
# 920 files processed, current file:  audios/segments/working_219.wav
# 940 files processed, current file:  audios/segments/working_239.wav
# 960 files processed, current file:  audios/segments/working_259.wav
# 980 files processed, current file:  audios/segments/working_279.wav
# 1000 files processed, current file:  audios/segments/working_299.wav
# 1020 files processed, current file:  audios/segments/working_319.wav
# 1040 files processed, current file:  audios/segments/working_339.wav
# 1060 files processed, current file:  audios/segments/working_359.wav
# 1080 files processed, current file:  audios/segments/working_379.wav
# 1100 files processed, current file:  audios/segments/working_399.wav
# 1120 files processed, current file:  audios/segments/working_419.wav
# 1140 files processed, current file:  audios/segments/working_439.wav
# 1160 files processed, current file:  audios/segments/working_459.wav
# 1180 files processed, current file:  audios/segments/working_479.wav
# 1200 files processed, current file:  audios/segments/working_499.wav
# 1220 files processed, current file:  audios/segments/working_519.wav
# 1240 files processed, current file:  audios/segments/working_539.wav
# 1260 files processed, current file:  audios/segments/working_559.wav
# 1280 files processed, current file:  audios/segments/working_579.wav
# 1300 files processed, current file:  audios/segments/working_599.wav
# 1320 files processed, current file:  audios/segments/working_619.wav
# 1340 files processed, current file:  audios/segments/working_639.wav
# 1360 files processed, current file:  audios/segments/working_659.wav
# 1380 files processed, current file:  audios/segments/working_679.wav
# 1400 files processed, current file:  audios/segments/working_699.wav
# 1420 files processed, current file:  audios/segments/cooling_19.wav
# 1440 files processed, current file:  audios/segments/cooling_39.wav
# 1460 files processed, current file:  audios/segments/cooling_59.wav
# 1480 files processed, current file:  audios/segments/cooling_79.wav
# 1500 files processed, current file:  audios/segments/cooling_99.wav
# 1520 files processed, current file:  audios/segments/cooling_119.wav
# 1540 files processed, current file:  audios/segments/cooling_139.wav
# 1560 files processed, current file:  audios/segments/cooling_159.wav
# 1580 files processed, current file:  audios/segments/cooling_179.wav
# 1600 files processed, current file:  audios/segments/cooling_199.wav
# 1620 files processed, current file:  audios/segments/cooling_219.wav
# 1640 files processed, current file:  audios/segments/cooling_239.wav
# 1660 files processed, current file:  audios/segments/cooling_259.wav
# 1680 files processed, current file:  audios/segments/cooling_279.wav
# 1700 files processed, current file:  audios/segments/cooling_299.wav
# 1720 files processed, current file:  audios/segments/cooling_319.wav
# 1740 files processed, current file:  audios/segments/cooling_339.wav
# 1760 files processed, current file:  audios/segments/cooling_359.wav
# 1780 files processed, current file:  audios/segments/cooling_379.wav
# 1800 files processed, current file:  audios/segments/cooling_399.wav
# 1820 files processed, current file:  audios/segments/cooling_419.wav
# 1840 files processed, current file:  audios/segments/cooling_439.wav
# 1860 files processed, current file:  audios/segments/cooling_459.wav
# 1880 files processed, current file:  audios/segments/cooling_479.wav
# 1900 files processed, current file:  audios/segments/cooling_499.wav
# 1920 files processed, current file:  audios/segments/cooling_519.wav
# 1940 files processed, current file:  audios/segments/cooling_539.wav
# 1960 files processed, current file:  audios/segments/cooling_559.wav
# 1980 files processed, current file:  audios/segments/cooling_579.wav
# 2000 files processed, current file:  audios/segments/cooling_599.wav
# 2020 files processed, current file:  audios/segments/cooling_619.wav
# 2040 files processed, current file:  audios/segments/cooling_639.wav
# 2060 files processed, current file:  audios/segments/cooling_659.wav
# 2080 files processed, current file:  audios/segments/cooling_679.wav
# 2100 files processed, current file:  audios/segments/cooling_699.wav
# 2120 files processed, current file:  audios/segments/silence_zoom_19.wav
# 2140 files processed, current file:  audios/segments/silence_zoom_39.wav
# 2160 files processed, current file:  audios/segments/silence_zoom_59.wav
# 2180 files processed, current file:  audios/segments/silence_zoom_79.wav
# 2200 files processed, current file:  audios/segments/silence_zoom_99.wav
# 2220 files processed, current file:  audios/segments/silence_zoom_119.wav
# 2240 files processed, current file:  audios/segments/silence_zoom_139.wav
# 2260 files processed, current file:  audios/segments/silence_zoom_159.wav
# 2280 files processed, current file:  audios/segments/silence_zoom_179.wav
# 2300 files processed, current file:  audios/segments/silence_zoom_199.wav
# 2320 files processed, current file:  audios/segments/silence_zoom_219.wav
# 2340 files processed, current file:  audios/segments/silence_zoom_239.wav
# 2360 files processed, current file:  audios/segments/silence_zoom_259.wav
# 2380 files processed, current file:  audios/segments/silence_zoom_279.wav
# 2400 files processed, current file:  audios/segments/silence_zoom_299.wav
# 2420 files processed, current file:  audios/segments/silence_zoom_319.wav
# 2440 files processed, current file:  audios/segments/silence_zoom_339.wav
# 2460 files processed, current file:  audios/segments/silence_zoom_359.wav
# 2480 files processed, current file:  audios/segments/silence_zoom_379.wav
# 2500 files processed, current file:  audios/segments/silence_zoom_399.wav
# 2520 files processed, current file:  audios/segments/silence_zoom_419.wav
# 2540 files processed, current file:  audios/segments/silence_zoom_439.wav
# 2560 files processed, current file:  audios/segments/silence_zoom_459.wav
# 2580 files processed, current file:  audios/segments/silence_zoom_479.wav
# 2600 files processed, current file:  audios/segments/silence_zoom_499.wav
# 2620 files processed, current file:  audios/segments/silence_zoom_519.wav
# 2640 files processed, current file:  audios/segments/silence_zoom_539.wav
# 2660 files processed, current file:  audios/segments/silence_zoom_559.wav
# 2680 files processed, current file:  audios/segments/silence_zoom_579.wav
# 2700 files processed, current file:  audios/segments/silence_zoom_599.wav
# 2720 files processed, current file:  audios/segments/silence_zoom_619.wav
# 2740 files processed, current file:  audios/segments/silence_zoom_639.wav
# 2760 files processed, current file:  audios/segments/silence_zoom_659.wav
# 2780 files processed, current file:  audios/segments/silence_zoom_679.wav
# 2800 files processed, current file:  audios/segments/silence_zoom_699.wav
# 2820 files processed, current file:  audios/segments/working_zoom_19.wav
# 2840 files processed, current file:  audios/segments/working_zoom_39.wav
# 2860 files processed, current file:  audios/segments/working_zoom_59.wav
# 2880 files processed, current file:  audios/segments/working_zoom_79.wav
# 2900 files processed, current file:  audios/segments/working_zoom_99.wav
# 2920 files processed, current file:  audios/segments/working_zoom_119.wav
# 2940 files processed, current file:  audios/segments/working_zoom_139.wav
# 2960 files processed, current file:  audios/segments/working_zoom_159.wav
# 2980 files processed, current file:  audios/segments/working_zoom_179.wav
# 3000 files processed, current file:  audios/segments/working_zoom_199.wav
# 3020 files processed, current file:  audios/segments/working_zoom_219.wav
# 3040 files processed, current file:  audios/segments/working_zoom_239.wav
# 3060 files processed, current file:  audios/segments/working_zoom_259.wav
# 3080 files processed, current file:  audios/segments/working_zoom_279.wav
# 3100 files processed, current file:  audios/segments/working_zoom_299.wav
# 3120 files processed, current file:  audios/segments/working_zoom_319.wav
# 3140 files processed, current file:  audios/segments/working_zoom_339.wav
# 3160 files processed, current file:  audios/segments/working_zoom_359.wav
# 3180 files processed, current file:  audios/segments/working_zoom_379.wav
# 3200 files processed, current file:  audios/segments/working_zoom_399.wav
# 3220 files processed, current file:  audios/segments/working_zoom_419.wav
# 3240 files processed, current file:  audios/segments/working_zoom_439.wav
# 3260 files processed, current file:  audios/segments/working_zoom_459.wav
# 3280 files processed, current file:  audios/segments/working_zoom_479.wav
# 3300 files processed, current file:  audios/segments/working_zoom_499.wav
# 3320 files processed, current file:  audios/segments/working_zoom_519.wav
# 3340 files processed, current file:  audios/segments/working_zoom_539.wav
# 3360 files processed, current file:  audios/segments/working_zoom_559.wav
# 3380 files processed, current file:  audios/segments/working_zoom_579.wav
# 3400 files processed, current file:  audios/segments/working_zoom_599.wav
# 3420 files processed, current file:  audios/segments/working_zoom_619.wav
# 3440 files processed, current file:  audios/segments/working_zoom_639.wav
# 3460 files processed, current file:  audios/segments/working_zoom_659.wav
# 3480 files processed, current file:  audios/segments/working_zoom_679.wav
# 3500 files processed, current file:  audios/segments/working_zoom_699.wav
# 3520 files processed, current file:  audios/segments/cooling_zoom_19.wav
# 3540 files processed, current file:  audios/segments/cooling_zoom_39.wav
# 3560 files processed, current file:  audios/segments/cooling_zoom_59.wav
# 3580 files processed, current file:  audios/segments/cooling_zoom_79.wav
# 3600 files processed, current file:  audios/segments/cooling_zoom_99.wav
# 3620 files processed, current file:  audios/segments/cooling_zoom_119.wav
# 3640 files processed, current file:  audios/segments/cooling_zoom_139.wav
# 3660 files processed, current file:  audios/segments/cooling_zoom_159.wav
# 3680 files processed, current file:  audios/segments/cooling_zoom_179.wav
# 3700 files processed, current file:  audios/segments/cooling_zoom_199.wav
# 3720 files processed, current file:  audios/segments/cooling_zoom_219.wav
# 3740 files processed, current file:  audios/segments/cooling_zoom_239.wav
# A total of  3756 files processed
# [667.9938354492188, 4652644.5]

# %% [markdown]
# ## Analysis and preprocessing of features
#
# All extracted features are saved in data.csv. Columns represent features and rows files/samples. This is a typical format in a large number of machine learning datasets (see a few of the dataset here: https://archive.ics.uci.edu/ml/index.php or other "Data Science" examples on the web).
#
# ***The use of a common format for data representation is beneficial in both making use of existing tools/libraries (such as Pandas) and contributing to the community with resources that are easy to use.***
#
# Let's load the data and start investigating the features. We can use Pandas (a package largely used in data science) to read data and access statistical description of the features.
#
# Remember that we created two data files, so we must read both of them separatedly.

# %%
import pandas as pd

# %%
#Read data
data_train = pd.read_csv(data_file_train)
data_validation = pd.read_csv(data_file_validation)
#Let's see the first lines of our data
data_train.head()
# Out:
#    spectral_centroid.mean  spectral_spread.mean    state
# 0              550.587585             5950551.5  silence
# 1              869.436035             8215683.0  silence
# 2             1041.962402             8563184.0  silence
# 3             1107.188232             8802325.0  silence
# 4             1632.097168            10751251.0  silence

# %% [markdown]
# All features are represented with columns, and the column ('state') carries the class information.

# %% [markdown]
# Always check if your data involves NaN values and clean them (by simply removing the sample, or replacing the NaN value by a real value (such as the median of that feature)).

# %%
#sums a matrix of True/False values obtained by checking if each value is Nan
data_train.isnull().sum().sum()
data_validation.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **Observation:** No NaN value, proceed ..
#
# We can plot samples on two-dimensional feature spaces to check if features are discriminative for those classes. Here is an example:

# %%
import seaborn as sns
sns.relplot(x = "spectral_centroid.mean", y = "spectral_spread.mean", hue = "state", style = "state", data = data_train);

# %% [markdown]
# The Seaborn package includes some very useful plotting functions that facilitate such visual inspections. Here is another example: this time producing plots **for the last 6 features**, creating all combinations to form 2-dimensional feature spaces representing the samples from different classes

# %%
sns.pairplot(data_train.iloc[:, -4:], hue = "state");

# %% [markdown]
# As the next step, having a look at descriptive statistics of the features would be useful. Let's do that:

# %%
#Descriptive statistics of the features:
data_train.describe()
# Out:
#        spectral_centroid.mean  spectral_spread.mean
# count             2100.000000          2.100000e+03
# mean              1142.220936          5.770394e+06
# std                445.708272          1.693107e+06
# min                294.828400          3.513348e+06
# 25%                734.260223          4.267426e+06
# 50%               1000.060852          5.373020e+06
# 75%               1605.157440          7.409605e+06
# max               4011.824951          1.384521e+07

# %% [markdown]
# **Observation:** min, max, mean values of the features vary a lot, we need to normalise them. Some of the features (such as average loudness) may be irrelevant for the task (check variance of the features). For simplicity of the code here, we will keep all the features as is, but you should consider removing irrelevant features from the list.
#
# ### Preprocessing of the features
#
# **Normalisation of the features**

# %%
data_train_modif = data_train.copy()
data_validation_modif = data_validation.copy()
#Let's use sklearn's preprocessing tools for applying normalisation to features
from sklearn import preprocessing
min_max_scaler_train = preprocessing.MinMaxScaler()
min_max_scaler_validation = preprocessing.MinMaxScaler()
data_train_modif.iloc[:,:num_of_descriptors] = min_max_scaler_train.fit_transform(data_train.iloc[:,:num_of_descriptors].values)
data_validation_modif.iloc[:,:num_of_descriptors] = min_max_scaler_validation.fit_transform(data_validation.iloc[:,:num_of_descriptors].values)

# %%
data_train_modif.describe()
# Out:
#        spectral_centroid.mean  spectral_spread.mean
# count             2100.000000           2100.000000
# mean                 0.227978              0.218455
# std                  0.119911              0.163872
# min                  0.000000              0.000000
# 25%                  0.118222              0.072986
# 50%                  0.189732              0.179994
# 75%                  0.352524              0.377111
# max                  1.000000              1.000000

# %% [markdown]
# **Observation:** Now the features are normalised in [0,1] range, proceed to converting data into matrices that can be fed into classifiers.
#
# We should check if our data is balanced (if there are the same number of samples for each class).
#
# Let's start with the train set:

# %%
samples_per_class_train = data_train_modif.state.value_counts().to_numpy()
data_train_modif.state.value_counts()
# Out:
# cooling    700
# silence    700
# working    700
# Name: state, dtype: int64

# %% [markdown]
# And now the validation set:

# %%
samples_per_class_validation = data_validation_modif.state.value_counts().to_numpy()
data_validation_modif.state.value_counts()
# Out:
# silence    700
# working    700
# cooling    256
# Name: state, dtype: int64

# %% [markdown]
# **Observation:** WE MUST BALANCE THE DATA IF IT IS NOT.
#
# ### Balancing the data
# If the data needs to be balanced, we will discard samples from the classes that have more samples to force the number of samples for each class to match. If every class have the same amount of samples, this cell does not produce any changes.

# %%
min_number_train = min(samples_per_class_train) #Take minimum value of samples per class to balance the data
cooling_train_data = data_train_modif[data_train_modif.state == 'cooling'].sample(n = min_number_train, random_state = 42)
silence_train_data = data_train_modif[data_train_modif.state == 'silence'].sample(n = min_number_train, random_state = 42)
working_train_data = data_train_modif[data_train_modif.state == 'working'].sample(n = min_number_train, random_state = 42)
#Merging after downsampling
data_train_modif = pd.concat([cooling_train_data, silence_train_data, working_train_data])
#Checking the balance again
data_train_modif.state.value_counts()
# Out:
# cooling    700
# silence    700
# working    700
# Name: state, dtype: int64

# %%
min_number_validation = min(samples_per_class_validation) #Take min value of samples per class to balance the data
cooling_validation_data = data_validation_modif[data_validation_modif.state == 'cooling'].sample(n = min_number_validation, random_state = 42)
silence_validation_data = data_validation_modif[data_validation_modif.state == 'silence'].sample(n = min_number_validation, random_state = 42)
working_validation_data = data_validation_modif[data_validation_modif.state == 'working'].sample(n = min_number_validation, random_state = 42)
#Merging after downsampling
data_validation_modif = pd.concat([cooling_validation_data, silence_validation_data, working_validation_data])
#Checking the balance again
data_validation_modif.state.value_counts()
# Out:
# silence    256
# cooling    256
# working    256
# Name: state, dtype: int64

# %% [markdown]
# ## Training an automatic classifier and testing it

# %% [markdown]
# **Preparing data arrays for features (inputs, X) and labels (outputs, y):**
#
# Now, we can form the input-output matrices that can be fed into classifiers. You can refer to [the tutorials of the scikit learn package](https://scikit-learn.org/stable/tutorial/index.html) to get familiar with the input-output formats.

# %%
X_train = data_train_modif.iloc[:,:num_of_descriptors].values
X_validation = data_validation_modif.iloc[:,:num_of_descriptors].values 

# Creating output values
data_train_modif.state = pd.Categorical(data_train_modif.state) #convert train to categorical data
data_validation_modif.state = pd.Categorical(data_validation_modif.state) #convert validation to categorical data
y_train = np.array(data_train_modif.state.cat.codes) #create label encoded outputs
y_validation = np.array(data_validation_modif.state.cat.codes) #create label encoded outputs

#Print the first sample of train and validation
print("Features of the first train sample: ", X_train[0])
print("Features of the first validation sample: ", X_validation[0])
print("Class of the first train sample: ", y_train[0])
print("Class of the first validation sample: ", y_validation[0])
# Out:
# Features of the first train sample:  [0.10600832 0.02615924]
# Features of the first validation sample:  [0.09540931 0.06918025]
# Class of the first train sample:  0
# Class of the first validation sample:  0

# %% [markdown]
# Let's check content of the outputs vector

# %%
#All output values: ebclar: 0, flute: 1, vibraphone: 2, violin: 3
print(y_train)
# Out:
# [0 0 0 ... 2 2 2]

# %%
print("Size of train features matrix: ",X_train.shape, ", Size of train output vector: ",y_train.shape)
print("Size of validation features matrix: ",X_validation.shape, ", Size of validation output vector: ",y_validation.shape)
# Out:
# Size of train features matrix:  (2100, 2) , Size of train output vector:  (2100,)
# Size of validation features matrix:  (768, 2) , Size of validation output vector:  (768,)

# %% [markdown]
# **Defining the machine learning model and training it**
#
# Now we can train a machine learning model. Let's pick a Support Vector Machine (SVM) model and feed our data to train it.

# %%
from sklearn import svm
clf = svm.SVC(gamma = 1 / (X_train.shape[-1] * X_train.var()))
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=24.237452733393255,
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# **validating the model**
#
# The model is trained. Now, one can perform prediction using the model for a given set of features. If we feed the features of the validation set, we expect to find the classes of the validation set (true values of it are stored in y_validation). We will refer to the output as "predicted classes (y_pred)."
#
# Then we will use the results obtained to modify the model settings in order to achieve the better accuracy with the less computational cost as possible.

# %%
y_pred = clf.predict(X_validation)

# %%
#Let's check for each sample in the validation set if prediction matches the true class information
y_validation == y_pred
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#        False,  True, False,  True,  True,  True,  True, False,  True,
#        False,  True, False,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#        False, False,  True, False,  True, False,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True, False,  True,
#        False,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True, False,  True,  True, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True, False,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True, False,  True,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#        False,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True, False,
#         True, False,  True,  True,  True,  True, False,  True,  True,
#         True, False, False, False,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
# Data is balanced, so you can use accuracy as a measure:
print("Accuracy: ", np.sum(y_validation == y_pred)/len(y_validation))
# Out:
# Accuracy:  0.9244791666666666

# %% [markdown]
# We want the accuracy to be over 0.99 (as we are talking about a real life market product!) and if it does not work with a substantial guarantee it cannot be considered a useful product...

# %% [markdown]
# As the final step, let's also print the **confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

classes = np.unique(data_train_modif.state)
conf_mat = pd.DataFrame(confusion_matrix(y_validation, y_pred), columns = classes, index = classes)
conf_mat.index.name = 'Actual'
conf_mat.columns.name = 'Predicted'
plt.figure(figsize = (7, 5))
sns.set(font_scale = 1.2)
sns.heatmap(conf_mat, cmap = "Blues", annot_kws = {"size": 12}, annot = True);

# %% [markdown]
# ### TO DO: ONCE THE MODEL IS DEFINED, IMPORT THE TEST SET AND TEST THE OVERALL ACCURACY OF OUR MODEL.
#
# **Stand-alone use of a trained model:**
#
# Now that we have a trained model, we have the tools to perform automatic instrument classification of isolated notes. Below, you find the code to run classification on audio files. This cell does not aim testing (because it also includes the training samples) but just a demonstration of the predictions of our model.

# %%
#Class names dictionary
classes = { 0: 'cooling', 1: 'silence', 2: 'working'}

#Here is the standalone function to run prediction for a given audio file
def predict_state(file, selected_feature_names, normalizer, classes, classifier):
    '''Predicts the instrument class for the given audio file
    '''
    #Extract features for a given file
    features, features_frames = es.MusicExtractor(lowlevelSilentFrames='drop',
                                                      lowlevelFrameSize = 2048,
                                                      lowlevelHopSize = 1024,
                                                      lowlevelStats = ['mean', 'stdev'])(file)
    #Pick the features we have used in our model
    selected_features = [features[descriptor] for descriptor in scalar_lowlevel_descriptors]
    #Applying learned scaling to the features
    scaled_features = min_max_scaler.transform(np.array(selected_features).reshape(1, -1))

    #Running prediction
    y_pred = classifier.predict(scaled_features)
    #Return predicted class 
    return classes[y_pred[0]]
#--------------------------------------------------------------------
#Running prediction on individual files
for file in segment_files:
    state_pred = predict_state(file, scalar_lowlevel_descriptors, min_max_scaler, classes, clf)

    #Printing the output
    print(file, " predicted as ", state_pred)

#!!! This is not a test (as it also contains training samples) but a simple demonstration 
# running standalone classifier on all files

# %% [markdown]
# ### Comparing classifiers
#
# Above, we have carried tests for one type of classifier. It is a common practice to compare performances of various classifiers with various settings. Below, we provide an example of such comparison on a limited set of classifiers.

# %%
#Edited version of https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html
import warnings
warnings.filterwarnings('ignore')#suppress warnings
#importing various classifiers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.naive_bayes import GaussianNB

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma = 1 / (X_train.shape[-1] * X_train.var())),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    MLPClassifier(alpha=1, max_iter=1000),
    GaussianNB()]

names = ["KNN", "Linear SVM", "RBF SVM", "Gaussian Process","Neural Net", "Naive Bayes"]

#Creating empty list of scores for each classifier, we will append test results to these lists 
scores = {}
for name in names:
    scores[name] = []

#Let's split our data into test and train
X_train_val, X_test, y_train_val, y_test = train_test_split(X_train, y_train, test_size = 0.20, random_state = 1)

#Let's run 10 random experiments, collect scores for each classifier 
num_tests = 10
for iteration_number in range(num_tests):
    x_train, x_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size = 1/num_tests, random_state = iteration_number)
    #normalisation of the data (learned from training data, applied to test data)
    scaler = StandardScaler().fit(x_train)
    norm_x_train = scaler.transform(x_train)
    norm_x_val = scaler.transform(x_val)
    
    # test over each classifier
    for name, clf in zip(names, classifiers):
        clf.fit(norm_x_train, y_train)#train
        score = clf.score(norm_x_val, y_val)#test
        scores[name].append(score)

for name, score in scores.items():
    print("{0}: acc = {1:1.2f}, +-{2:1.2f},\tvalues: {3}".format(name, np.mean(score), np.std(score), np.around(score, decimals = 2)))

# %% [markdown]
# Following this comparison, you can pick the classifier with highest performance, and report its performance on the test set

# %%
scaler = StandardScaler().fit(X_train_val)
norm_x_train_val = scaler.transform(X_train_val)
norm_x_test = scaler.transform(X_test)
selected_model = SVC(kernel="linear", C=0.025)#Linear SVM performance is high, let's pick that one
selected_model.fit(norm_x_train_val,y_train_val)
y_pred = selected_model.predict(norm_x_test)
print("Number of test samples: ", len(y_pred))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

# %% [markdown]
# <img src=https://miro.medium.com/max/974/1*CNWo23_VnUJPXdfrqbiB0g.jpeg width="400">
#
# <img src=https://www.oreilly.com/library/view/python-data-analysis/9781785282287/graphics/B04223_10_02.jpg width="250">

# %% [markdown]
# ### How about Deep Learning?
#
# We would often prefer deep learning based architectures when the data size is large. See Andrew Ng's figure from his [Coursera course](https://www.coursera.org/learn/neural-networks-deep-learning/):
#
# <img src=https://raw.githubusercontent.com/mbadry1/DeepLearning.ai-Summary/master/1-%20Neural%20Networks%20and%20Deep%20Learning/Images/11.png width="700">
#
# The data size in our case is small and the methods examplified above are just fine. Below, for the sake of presenting an example using a deep learning architecture, we build (with Keras) and train a DNN using the same features. For cases with larger data sets, feature extraction step can be dropped and end-to-end systems(audio->label) can be designed. Due to the size of our data, we will stick with our features.

# %%
#Let's start by splitting our data 
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1)
#..and apply normalisation
scaler = StandardScaler().fit(X_train_val)
norm_x_train_val = scaler.transform(X_train_val)
norm_x_test = scaler.transform(X_test)

# %% [markdown]
# Our neural network will have 4 neurons at the output layer each of which will output the estimated probability of the sample belonging to a class. So, let's convert our labels to **one-hot encoding** to fit to that representation.
# Example: a sample belonging to the 'violin' class is represented with 3 (integer encoded) will be represented with  [0 0 0 1]. Similarly, a 'ebclar' sample represented with with 0 will be represented with [1 0 0 0]

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)
y_train_val_onehot = onehot_encoder.fit_transform(y_train_val.reshape(len(y_train_val), 1))
y_test_onehot = onehot_encoder.fit_transform(y_test.reshape(len(y_test), 1))
print("One-hot encoded y_train_val shape = ", y_train_val_onehot.shape)
print("One-hot encoded y_test shape = ", y_test_onehot.shape)

# %% [markdown]
# **Let's define our deep learning architecture**

# %%
from keras.models import Sequential
from keras import layers

def compose_model(num_features):
    
    model = Sequential()

    # Input layer 
    model.add(layers.BatchNormalization(name='InputLayer', input_shape=(num_features,)))
    
    # 1. hidden layer
    model.add(layers.Dense(name='HiddenLayer_1', units = 40))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('tanh'))
    model.add(layers.Dropout(0.3))

    # 2. hidden layyer
    model.add(layers.Dense(name='HiddenLayer_2', units = 20))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))

    # Output layer
    model.add(layers.Dense(name='Output_layer', units = 4))
    model.add(layers.Activation('sigmoid'))
    
    return model

model = compose_model(X_train_val.shape[1])

# %% [markdown]
# You can have a look at the summary of the model

# %%
model.summary()

# %% [markdown]
# Let's pick an optimizer, compile the model and train the network

# %%
model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
summary = model.fit(X_train_val, y_train_val_onehot, batch_size = 50, epochs = 250, validation_split=0.2, verbose=0,)

# %% [markdown]
# Testing the trained model

# %%
score = model.evaluate(X_test, y_test_onehot, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# It is a good and common practice to check the learning curves

# %%
# summarize history for accuracy
plt.plot(summary.history['acc'])
plt.plot(summary.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
# summarize history for loss
plt.plot(summary.history['loss'])
plt.plot(summary.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
